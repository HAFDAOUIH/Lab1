# %% [markdown]
# # Import Necessary Libraries

# %%
import re
import qalsadi.lemmatizer as lemmatizer
import nltk
import pymongo
from nltk.tokenize import word_tokenize, sent_tokenize, TreebankWordTokenizer, WordPunctTokenizer, RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem.isri import ISRIStemmer

# %% [markdown]
# # Connect with mongoDB to fetchDATA from news_data

# %%
client = pymongo.MongoClient("mongodb://localhost:27017/")
db = client["news_data"]
collection = db["addustourspider"]

documents = collection.find()

# %% [markdown]
# # Function contain techniques to clean text and Normalisation and Discretization

# %%
def clean_text(text):
    # Remove HTML Tags
    html = re.compile(r'<[^>]+>')
    text = html.sub('', text)

    # Remove URLs
    url = re.compile(r'https?://\S+|www\.\S+')
    text = url.sub('', text)

    # Remove punctuation and numbers
    text = re.sub(r'[^\w\s]', '', text)

    # Remove Email IDs
    email = re.compile(r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b')
    text = email.sub('', text)

    # Remove Arabic diacritics (vowels and accents)
    arabic_diacritics = re.compile(r'[\u064B-\u065F\u0640]')
    text = arabic_diacritics.sub('', text)

    return text

# %% [markdown]
# # Lists to store original and cleaned texts

# %%
original_texts = []
cleaned_texts = []

# %% [markdown]
# # Loop through documents and clean text

# %%
for document in documents:
    original_text = document['content']
    cleaned_text = clean_text(original_text)

    # Adjust the limit in the 5 because will be often happens an error when trying to display large amounts of data after this boucle
    if len(original_texts) < 1:
        original_texts.append(original_text)
        cleaned_texts.append(cleaned_text)
    else:
        break
client.close()

# %% [markdown]
# # Tokenization

# %%
tokenizer = TreebankWordTokenizer()
Puncter = WordPunctTokenizer()
Regex = RegexpTokenizer("\w+|[^\w\s]")

# %% [markdown]
# # Tokenize cleaned text with all types to see the difference between them

# %%
for  cleaned_ in cleaned_texts:
    #print("\nOriginal Text:\n")
    #print(original_)
    #print("\nCleaned Text:\n")
    #print(cleaned_)
    print('\n the result with Sentence Tokenization – Splitting sentences in the paragraph: \n')
    print(sent_tokenize(cleaned_))
    print("\n------------------------------\n")
    print('\n the result with Word Tokenization – Splitting words in a sentence: \n')
    print(word_tokenize(cleaned_))
    print('\n the result with Word Tokenization – Using TreebankWordTokenizer: \n') #These tokenizers work by separating the words using punctuation and spaces.
    print(tokenizer.tokenize(cleaned_))
    print('\n the result with Word Tokenization – Using PunktWordTokenizer: \n')
    words = Puncter.tokenize(cleaned_)
    print(words)
    print('\n the result with Word Tokenization – Using Regular Expression: \n')
    print(Regex.tokenize(cleaned_))
# Out:
#  the result with Sentence Tokenization – Splitting sentences in the paragraph:
#
# ['شعرت بخسارة مريرة لأنني لم أكن بين جمهور مباراة كرة القدم الجميلة التي جمعت قبل أيام الفريقين العريقين الفيصلي والوحدات كم كنت سأكسب لو أني كنت معهم صوتا صادحا واحدا موحدا في هتاف بليغ قوي أغاظ ويغيظ أبناء الماء العكر وصياديه وينحاز إلى أردن عظيم بأطيافه وألوانه كوطن نحبه ونفديه بالمهج ولم يكن يوما إلا مع أهله في غزة وفلسطين وسندا لكل جرح عربي الهتافات العظيمة لامست شغاف قلبي ورقصتني بهجة فرغم أن أصوات غرابية عديدة كانت تبث سوداويتها وشؤمها مطالبة بإلغاء المباراة في الظرف العصيب الذي نمر فيه لأنهم يتخوفون من انقلاب المباراة إلى معركة دق خشوم و كسر عظم وطحن رؤوس لكني لم أكن أخاف أبدا من تلك المواجهة لأنني واثق في متانة وقوة مسبحتنا الوطنية\xa0 \xa0 لدي مسبحة مطعمة بالفضة عمرها ثلاثون عاما لها ذكريات طيبة في نفسي لكني لا أحبذ أن أظهرها ليس لأني أخشى عليها الانفراط حتى حين أدبك بها لا سمح الله بل لأنك قد تقف مع أحدهم فيمد يده لا شعوريا ويأخذها يتأملها ويداعب شراشيبها ويتفحص حجارتها ويسألك إن كانت حقا فيروزا فتهز رأسك مؤكدا ثم يكر عليها مرتين ويغافلك ويدسها في جيبه ويمضي في سوق شعبية كنت أتردد فيه على باعة المسابح في بغداد أسأل وأستفسر عن كل شاردة حتى كدت أصير خبيرا بأنواعها قادرا على أن أعرف الياقوت من السندلس من الفيروز والزبرجد وكل الأحجار الكريمة بل وأن أفصل الألون الطبيعية عن الصناعية مهما كانت دقة صنعها وأميز المسابح التي تفوح عطرا كلما فركت حجارتها في راحتيك وأقدر قيمتها وثمنها \xa0 في ذات السوق قال لي بائع مسن متغضن الوجه وقور إن المسبحة خيط أي عليك أن تنتقي خيطا لمسبحتك يكون قويا فلا فائدة من مسبحة تنقطع مع أول دورة جوبي ولهذا دعمت مسبحتي بخيط متين  نحن في العادة نلتفت إلى حجارة المسبحة وقيمة حباتها وألوانها فقط ولا نلتفت إلى الخيط الذي ينظم هذه الحبات فهو متوار مخفي عن الأنظار لكنه موجود لا نحس به إلا حين ينقطع وعندها فإن المسبحة لن تعود مسبحة والعقد لن يعود عقدا بل مجرد حبات متناثرة تطؤها الأقدام ويعفرها التراب حين يكون خيط مسبحتك ضعيفا يحق لك أن تخاف عليها لكن حين تكون واثقا من قوة ذلك الخيط ومتانته وأصالته لأنه الجوهر لا يبقى عليك إلا أن تنتبه من يد الغرباء أن تخطفها منك وتغافلك وتدسها في جيبها']
#
# ------------------------------
#
#
#  the result with Word Tokenization – Splitting words in a sentence:
#
# ['شعرت', 'بخسارة', 'مريرة', 'لأنني', 'لم', 'أكن', 'بين', 'جمهور', 'مباراة', 'كرة', 'القدم', 'الجميلة', 'التي', 'جمعت', 'قبل', 'أيام', 'الفريقين', 'العريقين', 'الفيصلي', 'والوحدات', 'كم', 'كنت', 'سأكسب', 'لو', 'أني', 'كنت', 'معهم', 'صوتا', 'صادحا', 'واحدا', 'موحدا', 'في', 'هتاف', 'بليغ', 'قوي', 'أغاظ', 'ويغيظ', 'أبناء', 'الماء', 'العكر', 'وصياديه', 'وينحاز', 'إلى', 'أردن', 'عظيم', 'بأطيافه', 'وألوانه', 'كوطن', 'نحبه', 'ونفديه', 'بالمهج', 'ولم', 'يكن', 'يوما', 'إلا', 'مع', 'أهله', 'في', 'غزة', 'وفلسطين', 'وسندا', 'لكل', 'جرح', 'عربي', 'الهتافات', 'العظيمة', 'لامست', 'شغاف', 'قلبي', 'ورقصتني', 'بهجة', 'فرغم', 'أن', 'أصوات', 'غرابية', 'عديدة', 'كانت', 'تبث', 'سوداويتها', 'وشؤمها', 'مطالبة', 'بإلغاء', 'المباراة', 'في', 'الظرف', 'العصيب', 'الذي', 'نمر', 'فيه', 'لأنهم', 'يتخوفون', 'من', 'انقلاب', 'المباراة', 'إلى', 'معركة', 'دق', 'خشوم', 'و', 'كسر', 'عظم', 'وطحن', 'رؤوس', 'لكني', 'لم', 'أكن', 'أخاف', 'أبدا', 'من', 'تلك', 'المواجهة', 'لأنني', 'واثق', 'في', 'متانة', 'وقوة', 'مسبحتنا', 'الوطنية', 'لدي', 'مسبحة', 'مطعمة', 'بالفضة', 'عمرها', 'ثلاثون', 'عاما', 'لها', 'ذكريات', 'طيبة', 'في', 'نفسي', 'لكني', 'لا', 'أحبذ', 'أن', 'أظهرها', 'ليس', 'لأني', 'أخشى', 'عليها', 'الانفراط', 'حتى', 'حين', 'أدبك', 'بها', 'لا', 'سمح', 'الله', 'بل', 'لأنك', 'قد', 'تقف', 'مع', 'أحدهم', 'فيمد', 'يده', 'لا', 'شعوريا', 'ويأخذها', 'يتأملها', 'ويداعب', 'شراشيبها', 'ويتفحص', 'حجارتها', 'ويسألك', 'إن', 'كانت', 'حقا', 'فيروزا', 'فتهز', 'رأسك', 'مؤكدا', 'ثم', 'يكر', 'عليها', 'مرتين', 'ويغافلك', 'ويدسها', 'في', 'جيبه', 'ويمضي', 'في', 'سوق', 'شعبية', 'كنت', 'أتردد', 'فيه', 'على', 'باعة', 'المسابح', 'في', 'بغداد', 'أسأل', 'وأستفسر', 'عن', 'كل', 'شاردة', 'حتى', 'كدت', 'أصير', 'خبيرا', 'بأنواعها', 'قادرا', 'على', 'أن', 'أعرف', 'الياقوت', 'من', 'السندلس', 'من', 'الفيروز', 'والزبرجد', 'وكل', 'الأحجار', 'الكريمة', 'بل', 'وأن', 'أفصل', 'الألون', 'الطبيعية', 'عن', 'الصناعية', 'مهما', 'كانت', 'دقة', 'صنعها', 'وأميز', 'المسابح', 'التي', 'تفوح', 'عطرا', 'كلما', 'فركت', 'حجارتها', 'في', 'راحتيك', 'وأقدر', 'قيمتها', 'وثمنها', 'في', 'ذات', 'السوق', 'قال', 'لي', 'بائع', 'مسن', 'متغضن', 'الوجه', 'وقور', 'إن', 'المسبحة', 'خيط', 'أي', 'عليك', 'أن', 'تنتقي', 'خيطا', 'لمسبحتك', 'يكون', 'قويا', 'فلا', 'فائدة', 'من', 'مسبحة', 'تنقطع', 'مع', 'أول', 'دورة', 'جوبي', 'ولهذا', 'دعمت', 'مسبحتي', 'بخيط', 'متين', 'نحن', 'في', 'العادة', 'نلتفت', 'إلى', 'حجارة', 'المسبحة', 'وقيمة', 'حباتها', 'وألوانها', 'فقط', 'ولا', 'نلتفت', 'إلى', 'الخيط', 'الذي', 'ينظم', 'هذه', 'الحبات', 'فهو', 'متوار', 'مخفي', 'عن', 'الأنظار', 'لكنه', 'موجود', 'لا', 'نحس', 'به', 'إلا', 'حين', 'ينقطع', 'وعندها', 'فإن', 'المسبحة', 'لن', 'تعود', 'مسبحة', 'والعقد', 'لن', 'يعود', 'عقدا', 'بل', 'مجرد', 'حبات', 'متناثرة', 'تطؤها', 'الأقدام', 'ويعفرها', 'التراب', 'حين', 'يكون', 'خيط', 'مسبحتك', 'ضعيفا', 'يحق', 'لك', 'أن', 'تخاف', 'عليها', 'لكن', 'حين', 'تكون', 'واثقا', 'من', 'قوة', 'ذلك', 'الخيط', 'ومتانته', 'وأصالته', 'لأنه', 'الجوهر', 'لا', 'يبقى', 'عليك', 'إلا', 'أن', 'تنتبه', 'من', 'يد', 'الغرباء', 'أن', 'تخطفها', 'منك', 'وتغافلك', 'وتدسها', 'في', 'جيبها']
#
#  the result with Word Tokenization – Using TreebankWordTokenizer:
#
# ['شعرت', 'بخسارة', 'مريرة', 'لأنني', 'لم', 'أكن', 'بين', 'جمهور', 'مباراة', 'كرة', 'القدم', 'الجميلة', 'التي', 'جمعت', 'قبل', 'أيام', 'الفريقين', 'العريقين', 'الفيصلي', 'والوحدات', 'كم', 'كنت', 'سأكسب', 'لو', 'أني', 'كنت', 'معهم', 'صوتا', 'صادحا', 'واحدا', 'موحدا', 'في', 'هتاف', 'بليغ', 'قوي', 'أغاظ', 'ويغيظ', 'أبناء', 'الماء', 'العكر', 'وصياديه', 'وينحاز', 'إلى', 'أردن', 'عظيم', 'بأطيافه', 'وألوانه', 'كوطن', 'نحبه', 'ونفديه', 'بالمهج', 'ولم', 'يكن', 'يوما', 'إلا', 'مع', 'أهله', 'في', 'غزة', 'وفلسطين', 'وسندا', 'لكل', 'جرح', 'عربي', 'الهتافات', 'العظيمة', 'لامست', 'شغاف', 'قلبي', 'ورقصتني', 'بهجة', 'فرغم', 'أن', 'أصوات', 'غرابية', 'عديدة', 'كانت', 'تبث', 'سوداويتها', 'وشؤمها', 'مطالبة', 'بإلغاء', 'المباراة', 'في', 'الظرف', 'العصيب', 'الذي', 'نمر', 'فيه', 'لأنهم', 'يتخوفون', 'من', 'انقلاب', 'المباراة', 'إلى', 'معركة', 'دق', 'خشوم', 'و', 'كسر', 'عظم', 'وطحن', 'رؤوس', 'لكني', 'لم', 'أكن', 'أخاف', 'أبدا', 'من', 'تلك', 'المواجهة', 'لأنني', 'واثق', 'في', 'متانة', 'وقوة', 'مسبحتنا', 'الوطنية', 'لدي', 'مسبحة', 'مطعمة', 'بالفضة', 'عمرها', 'ثلاثون', 'عاما', 'لها', 'ذكريات', 'طيبة', 'في', 'نفسي', 'لكني', 'لا', 'أحبذ', 'أن', 'أظهرها', 'ليس', 'لأني', 'أخشى', 'عليها', 'الانفراط', 'حتى', 'حين', 'أدبك', 'بها', 'لا', 'سمح', 'الله', 'بل', 'لأنك', 'قد', 'تقف', 'مع', 'أحدهم', 'فيمد', 'يده', 'لا', 'شعوريا', 'ويأخذها', 'يتأملها', 'ويداعب', 'شراشيبها', 'ويتفحص', 'حجارتها', 'ويسألك', 'إن', 'كانت', 'حقا', 'فيروزا', 'فتهز', 'رأسك', 'مؤكدا', 'ثم', 'يكر', 'عليها', 'مرتين', 'ويغافلك', 'ويدسها', 'في', 'جيبه', 'ويمضي', 'في', 'سوق', 'شعبية', 'كنت', 'أتردد', 'فيه', 'على', 'باعة', 'المسابح', 'في', 'بغداد', 'أسأل', 'وأستفسر', 'عن', 'كل', 'شاردة', 'حتى', 'كدت', 'أصير', 'خبيرا', 'بأنواعها', 'قادرا', 'على', 'أن', 'أعرف', 'الياقوت', 'من', 'السندلس', 'من', 'الفيروز', 'والزبرجد', 'وكل', 'الأحجار', 'الكريمة', 'بل', 'وأن', 'أفصل', 'الألون', 'الطبيعية', 'عن', 'الصناعية', 'مهما', 'كانت', 'دقة', 'صنعها', 'وأميز', 'المسابح', 'التي', 'تفوح', 'عطرا', 'كلما', 'فركت', 'حجارتها', 'في', 'راحتيك', 'وأقدر', 'قيمتها', 'وثمنها', 'في', 'ذات', 'السوق', 'قال', 'لي', 'بائع', 'مسن', 'متغضن', 'الوجه', 'وقور', 'إن', 'المسبحة', 'خيط', 'أي', 'عليك', 'أن', 'تنتقي', 'خيطا', 'لمسبحتك', 'يكون', 'قويا', 'فلا', 'فائدة', 'من', 'مسبحة', 'تنقطع', 'مع', 'أول', 'دورة', 'جوبي', 'ولهذا', 'دعمت', 'مسبحتي', 'بخيط', 'متين', 'نحن', 'في', 'العادة', 'نلتفت', 'إلى', 'حجارة', 'المسبحة', 'وقيمة', 'حباتها', 'وألوانها', 'فقط', 'ولا', 'نلتفت', 'إلى', 'الخيط', 'الذي', 'ينظم', 'هذه', 'الحبات', 'فهو', 'متوار', 'مخفي', 'عن', 'الأنظار', 'لكنه', 'موجود', 'لا', 'نحس', 'به', 'إلا', 'حين', 'ينقطع', 'وعندها', 'فإن', 'المسبحة', 'لن', 'تعود', 'مسبحة', 'والعقد', 'لن', 'يعود', 'عقدا', 'بل', 'مجرد', 'حبات', 'متناثرة', 'تطؤها', 'الأقدام', 'ويعفرها', 'التراب', 'حين', 'يكون', 'خيط', 'مسبحتك', 'ضعيفا', 'يحق', 'لك', 'أن', 'تخاف', 'عليها', 'لكن', 'حين', 'تكون', 'واثقا', 'من', 'قوة', 'ذلك', 'الخيط', 'ومتانته', 'وأصالته', 'لأنه', 'الجوهر', 'لا', 'يبقى', 'عليك', 'إلا', 'أن', 'تنتبه', 'من', 'يد', 'الغرباء', 'أن', 'تخطفها', 'منك', 'وتغافلك', 'وتدسها', 'في', 'جيبها']
#
#  the result with Word Tokenization – Using PunktWordTokenizer:
#
# ['شعرت', 'بخسارة', 'مريرة', 'لأنني', 'لم', 'أكن', 'بين', 'جمهور', 'مباراة', 'كرة', 'القدم', 'الجميلة', 'التي', 'جمعت', 'قبل', 'أيام', 'الفريقين', 'العريقين', 'الفيصلي', 'والوحدات', 'كم', 'كنت', 'سأكسب', 'لو', 'أني', 'كنت', 'معهم', 'صوتا', 'صادحا', 'واحدا', 'موحدا', 'في', 'هتاف', 'بليغ', 'قوي', 'أغاظ', 'ويغيظ', 'أبناء', 'الماء', 'العكر', 'وصياديه', 'وينحاز', 'إلى', 'أردن', 'عظيم', 'بأطيافه', 'وألوانه', 'كوطن', 'نحبه', 'ونفديه', 'بالمهج', 'ولم', 'يكن', 'يوما', 'إلا', 'مع', 'أهله', 'في', 'غزة', 'وفلسطين', 'وسندا', 'لكل', 'جرح', 'عربي', 'الهتافات', 'العظيمة', 'لامست', 'شغاف', 'قلبي', 'ورقصتني', 'بهجة', 'فرغم', 'أن', 'أصوات', 'غرابية', 'عديدة', 'كانت', 'تبث', 'سوداويتها', 'وشؤمها', 'مطالبة', 'بإلغاء', 'المباراة', 'في', 'الظرف', 'العصيب', 'الذي', 'نمر', 'فيه', 'لأنهم', 'يتخوفون', 'من', 'انقلاب', 'المباراة', 'إلى', 'معركة', 'دق', 'خشوم', 'و', 'كسر', 'عظم', 'وطحن', 'رؤوس', 'لكني', 'لم', 'أكن', 'أخاف', 'أبدا', 'من', 'تلك', 'المواجهة', 'لأنني', 'واثق', 'في', 'متانة', 'وقوة', 'مسبحتنا', 'الوطنية', 'لدي', 'مسبحة', 'مطعمة', 'بالفضة', 'عمرها', 'ثلاثون', 'عاما', 'لها', 'ذكريات', 'طيبة', 'في', 'نفسي', 'لكني', 'لا', 'أحبذ', 'أن', 'أظهرها', 'ليس', 'لأني', 'أخشى', 'عليها', 'الانفراط', 'حتى', 'حين', 'أدبك', 'بها', 'لا', 'سمح', 'الله', 'بل', 'لأنك', 'قد', 'تقف', 'مع', 'أحدهم', 'فيمد', 'يده', 'لا', 'شعوريا', 'ويأخذها', 'يتأملها', 'ويداعب', 'شراشيبها', 'ويتفحص', 'حجارتها', 'ويسألك', 'إن', 'كانت', 'حقا', 'فيروزا', 'فتهز', 'رأسك', 'مؤكدا', 'ثم', 'يكر', 'عليها', 'مرتين', 'ويغافلك', 'ويدسها', 'في', 'جيبه', 'ويمضي', 'في', 'سوق', 'شعبية', 'كنت', 'أتردد', 'فيه', 'على', 'باعة', 'المسابح', 'في', 'بغداد', 'أسأل', 'وأستفسر', 'عن', 'كل', 'شاردة', 'حتى', 'كدت', 'أصير', 'خبيرا', 'بأنواعها', 'قادرا', 'على', 'أن', 'أعرف', 'الياقوت', 'من', 'السندلس', 'من', 'الفيروز', 'والزبرجد', 'وكل', 'الأحجار', 'الكريمة', 'بل', 'وأن', 'أفصل', 'الألون', 'الطبيعية', 'عن', 'الصناعية', 'مهما', 'كانت', 'دقة', 'صنعها', 'وأميز', 'المسابح', 'التي', 'تفوح', 'عطرا', 'كلما', 'فركت', 'حجارتها', 'في', 'راحتيك', 'وأقدر', 'قيمتها', 'وثمنها', 'في', 'ذات', 'السوق', 'قال', 'لي', 'بائع', 'مسن', 'متغضن', 'الوجه', 'وقور', 'إن', 'المسبحة', 'خيط', 'أي', 'عليك', 'أن', 'تنتقي', 'خيطا', 'لمسبحتك', 'يكون', 'قويا', 'فلا', 'فائدة', 'من', 'مسبحة', 'تنقطع', 'مع', 'أول', 'دورة', 'جوبي', 'ولهذا', 'دعمت', 'مسبحتي', 'بخيط', 'متين', 'نحن', 'في', 'العادة', 'نلتفت', 'إلى', 'حجارة', 'المسبحة', 'وقيمة', 'حباتها', 'وألوانها', 'فقط', 'ولا', 'نلتفت', 'إلى', 'الخيط', 'الذي', 'ينظم', 'هذه', 'الحبات', 'فهو', 'متوار', 'مخفي', 'عن', 'الأنظار', 'لكنه', 'موجود', 'لا', 'نحس', 'به', 'إلا', 'حين', 'ينقطع', 'وعندها', 'فإن', 'المسبحة', 'لن', 'تعود', 'مسبحة', 'والعقد', 'لن', 'يعود', 'عقدا', 'بل', 'مجرد', 'حبات', 'متناثرة', 'تطؤها', 'الأقدام', 'ويعفرها', 'التراب', 'حين', 'يكون', 'خيط', 'مسبحتك', 'ضعيفا', 'يحق', 'لك', 'أن', 'تخاف', 'عليها', 'لكن', 'حين', 'تكون', 'واثقا', 'من', 'قوة', 'ذلك', 'الخيط', 'ومتانته', 'وأصالته', 'لأنه', 'الجوهر', 'لا', 'يبقى', 'عليك', 'إلا', 'أن', 'تنتبه', 'من', 'يد', 'الغرباء', 'أن', 'تخطفها', 'منك', 'وتغافلك', 'وتدسها', 'في', 'جيبها']
#
#  the result with Word Tokenization – Using Regular Expression:
#
# ['شعرت', 'بخسارة', 'مريرة', 'لأنني', 'لم', 'أكن', 'بين', 'جمهور', 'مباراة', 'كرة', 'القدم', 'الجميلة', 'التي', 'جمعت', 'قبل', 'أيام', 'الفريقين', 'العريقين', 'الفيصلي', 'والوحدات', 'كم', 'كنت', 'سأكسب', 'لو', 'أني', 'كنت', 'معهم', 'صوتا', 'صادحا', 'واحدا', 'موحدا', 'في', 'هتاف', 'بليغ', 'قوي', 'أغاظ', 'ويغيظ', 'أبناء', 'الماء', 'العكر', 'وصياديه', 'وينحاز', 'إلى', 'أردن', 'عظيم', 'بأطيافه', 'وألوانه', 'كوطن', 'نحبه', 'ونفديه', 'بالمهج', 'ولم', 'يكن', 'يوما', 'إلا', 'مع', 'أهله', 'في', 'غزة', 'وفلسطين', 'وسندا', 'لكل', 'جرح', 'عربي', 'الهتافات', 'العظيمة', 'لامست', 'شغاف', 'قلبي', 'ورقصتني', 'بهجة', 'فرغم', 'أن', 'أصوات', 'غرابية', 'عديدة', 'كانت', 'تبث', 'سوداويتها', 'وشؤمها', 'مطالبة', 'بإلغاء', 'المباراة', 'في', 'الظرف', 'العصيب', 'الذي', 'نمر', 'فيه', 'لأنهم', 'يتخوفون', 'من', 'انقلاب', 'المباراة', 'إلى', 'معركة', 'دق', 'خشوم', 'و', 'كسر', 'عظم', 'وطحن', 'رؤوس', 'لكني', 'لم', 'أكن', 'أخاف', 'أبدا', 'من', 'تلك', 'المواجهة', 'لأنني', 'واثق', 'في', 'متانة', 'وقوة', 'مسبحتنا', 'الوطنية', 'لدي', 'مسبحة', 'مطعمة', 'بالفضة', 'عمرها', 'ثلاثون', 'عاما', 'لها', 'ذكريات', 'طيبة', 'في', 'نفسي', 'لكني', 'لا', 'أحبذ', 'أن', 'أظهرها', 'ليس', 'لأني', 'أخشى', 'عليها', 'الانفراط', 'حتى', 'حين', 'أدبك', 'بها', 'لا', 'سمح', 'الله', 'بل', 'لأنك', 'قد', 'تقف', 'مع', 'أحدهم', 'فيمد', 'يده', 'لا', 'شعوريا', 'ويأخذها', 'يتأملها', 'ويداعب', 'شراشيبها', 'ويتفحص', 'حجارتها', 'ويسألك', 'إن', 'كانت', 'حقا', 'فيروزا', 'فتهز', 'رأسك', 'مؤكدا', 'ثم', 'يكر', 'عليها', 'مرتين', 'ويغافلك', 'ويدسها', 'في', 'جيبه', 'ويمضي', 'في', 'سوق', 'شعبية', 'كنت', 'أتردد', 'فيه', 'على', 'باعة', 'المسابح', 'في', 'بغداد', 'أسأل', 'وأستفسر', 'عن', 'كل', 'شاردة', 'حتى', 'كدت', 'أصير', 'خبيرا', 'بأنواعها', 'قادرا', 'على', 'أن', 'أعرف', 'الياقوت', 'من', 'السندلس', 'من', 'الفيروز', 'والزبرجد', 'وكل', 'الأحجار', 'الكريمة', 'بل', 'وأن', 'أفصل', 'الألون', 'الطبيعية', 'عن', 'الصناعية', 'مهما', 'كانت', 'دقة', 'صنعها', 'وأميز', 'المسابح', 'التي', 'تفوح', 'عطرا', 'كلما', 'فركت', 'حجارتها', 'في', 'راحتيك', 'وأقدر', 'قيمتها', 'وثمنها', 'في', 'ذات', 'السوق', 'قال', 'لي', 'بائع', 'مسن', 'متغضن', 'الوجه', 'وقور', 'إن', 'المسبحة', 'خيط', 'أي', 'عليك', 'أن', 'تنتقي', 'خيطا', 'لمسبحتك', 'يكون', 'قويا', 'فلا', 'فائدة', 'من', 'مسبحة', 'تنقطع', 'مع', 'أول', 'دورة', 'جوبي', 'ولهذا', 'دعمت', 'مسبحتي', 'بخيط', 'متين', 'نحن', 'في', 'العادة', 'نلتفت', 'إلى', 'حجارة', 'المسبحة', 'وقيمة', 'حباتها', 'وألوانها', 'فقط', 'ولا', 'نلتفت', 'إلى', 'الخيط', 'الذي', 'ينظم', 'هذه', 'الحبات', 'فهو', 'متوار', 'مخفي', 'عن', 'الأنظار', 'لكنه', 'موجود', 'لا', 'نحس', 'به', 'إلا', 'حين', 'ينقطع', 'وعندها', 'فإن', 'المسبحة', 'لن', 'تعود', 'مسبحة', 'والعقد', 'لن', 'يعود', 'عقدا', 'بل', 'مجرد', 'حبات', 'متناثرة', 'تطؤها', 'الأقدام', 'ويعفرها', 'التراب', 'حين', 'يكون', 'خيط', 'مسبحتك', 'ضعيفا', 'يحق', 'لك', 'أن', 'تخاف', 'عليها', 'لكن', 'حين', 'تكون', 'واثقا', 'من', 'قوة', 'ذلك', 'الخيط', 'ومتانته', 'وأصالته', 'لأنه', 'الجوهر', 'لا', 'يبقى', 'عليك', 'إلا', 'أن', 'تنتبه', 'من', 'يد', 'الغرباء', 'أن', 'تخطفها', 'منك', 'وتغافلك', 'وتدسها', 'في', 'جيبها']

# %% [markdown]
# # Stop words

# %%
stop_words = set(stopwords.words('arabic'))

# %% [markdown]
# # Filter words after applying stop words techniques

# %%
print('\n  Filtred words after applying the Stop words techniques: \n ')
Filtered_text = [word for word in words if not word in stop_words]
#Filtered_tafter ext = ' '.join(Filtered_text)
print(Filtered_text)
# Out:
#   Filtred words after applying the Stop words techniques:
#
# ['شعرت', 'بخسارة', 'مريرة', 'لأنني', 'أكن', 'جمهور', 'مباراة', 'كرة', 'القدم', 'الجميلة', 'جمعت', 'أيام', 'الفريقين', 'العريقين', 'الفيصلي', 'والوحدات', 'كنت', 'سأكسب', 'أني', 'كنت', 'معهم', 'صوتا', 'صادحا', 'واحدا', 'موحدا', 'هتاف', 'بليغ', 'قوي', 'أغاظ', 'ويغيظ', 'أبناء', 'الماء', 'العكر', 'وصياديه', 'وينحاز', 'أردن', 'عظيم', 'بأطيافه', 'وألوانه', 'كوطن', 'نحبه', 'ونفديه', 'بالمهج', 'ولم', 'يكن', 'يوما', 'أهله', 'غزة', 'وفلسطين', 'وسندا', 'لكل', 'جرح', 'عربي', 'الهتافات', 'العظيمة', 'لامست', 'شغاف', 'قلبي', 'ورقصتني', 'بهجة', 'فرغم', 'أصوات', 'غرابية', 'عديدة', 'كانت', 'تبث', 'سوداويتها', 'وشؤمها', 'مطالبة', 'بإلغاء', 'المباراة', 'الظرف', 'العصيب', 'نمر', 'لأنهم', 'يتخوفون', 'انقلاب', 'المباراة', 'معركة', 'دق', 'خشوم', 'كسر', 'عظم', 'وطحن', 'رؤوس', 'لكني', 'أكن', 'أخاف', 'المواجهة', 'لأنني', 'واثق', 'متانة', 'وقوة', 'مسبحتنا', 'الوطنية', 'لدي', 'مسبحة', 'مطعمة', 'بالفضة', 'عمرها', 'عاما', 'ذكريات', 'طيبة', 'نفسي', 'لكني', 'أحبذ', 'أظهرها', 'لأني', 'أخشى', 'عليها', 'الانفراط', 'أدبك', 'سمح', 'الله', 'لأنك', 'تقف', 'أحدهم', 'فيمد', 'يده', 'شعوريا', 'ويأخذها', 'يتأملها', 'ويداعب', 'شراشيبها', 'ويتفحص', 'حجارتها', 'ويسألك', 'كانت', 'فيروزا', 'فتهز', 'رأسك', 'مؤكدا', 'يكر', 'عليها', 'مرتين', 'ويغافلك', 'ويدسها', 'جيبه', 'ويمضي', 'سوق', 'شعبية', 'كنت', 'أتردد', 'باعة', 'المسابح', 'بغداد', 'أسأل', 'وأستفسر', 'شاردة', 'كدت', 'أصير', 'خبيرا', 'بأنواعها', 'قادرا', 'أعرف', 'الياقوت', 'السندلس', 'الفيروز', 'والزبرجد', 'وكل', 'الأحجار', 'الكريمة', 'وأن', 'أفصل', 'الألون', 'الطبيعية', 'الصناعية', 'كانت', 'دقة', 'صنعها', 'وأميز', 'المسابح', 'تفوح', 'عطرا', 'فركت', 'حجارتها', 'راحتيك', 'وأقدر', 'قيمتها', 'وثمنها', 'السوق', 'قال', 'بائع', 'مسن', 'متغضن', 'الوجه', 'وقور', 'المسبحة', 'خيط', 'تنتقي', 'خيطا', 'لمسبحتك', 'يكون', 'قويا', 'فائدة', 'مسبحة', 'تنقطع', 'دورة', 'جوبي', 'ولهذا', 'دعمت', 'مسبحتي', 'بخيط', 'متين', 'العادة', 'نلتفت', 'حجارة', 'المسبحة', 'وقيمة', 'حباتها', 'وألوانها', 'فقط', 'نلتفت', 'الخيط', 'ينظم', 'الحبات', 'فهو', 'متوار', 'مخفي', 'الأنظار', 'لكنه', 'موجود', 'نحس', 'ينقطع', 'وعندها', 'المسبحة', 'تعود', 'مسبحة', 'والعقد', 'يعود', 'عقدا', 'مجرد', 'حبات', 'متناثرة', 'تطؤها', 'الأقدام', 'ويعفرها', 'التراب', 'يكون', 'خيط', 'مسبحتك', 'ضعيفا', 'يحق', 'تخاف', 'عليها', 'تكون', 'واثقا', 'قوة', 'الخيط', 'ومتانته', 'وأصالته', 'لأنه', 'الجوهر', 'يبقى', 'تنتبه', 'يد', 'الغرباء', 'تخطفها', 'منك', 'وتغافلك', 'وتدسها', 'جيبها']

# %% [markdown]
# # Stemming and Lemmatization

# %%
lemmatizer = lemmatizer.Lemmatizer()
ISRI = ISRIStemmer()

# %%
print("\n-------------Stemming and Lemmatization Part----------------\n")
stemmed_words = [ISRI.stem(word) for word in Filtered_text]
print("Stemmed Words:")
print(stemmed_words)
# Out:
# -------------Stemming and Lemmatization Part----------------
#
# Stemmed Words:
# ['شعر', 'خسر', 'رير', 'لأن', 'اكن', 'جمهور', 'برا', 'كرة', 'قدم', 'جمل', 'جمع', 'ايم', 'فرق', 'عرق', 'يصل', 'وحد', 'كنت', 'أكسب', 'اني', 'كنت', 'عهم', 'صوت', 'صدح', 'وحد', 'وحد', 'هتف', 'بلغ', 'قوي', 'اغظ', 'يغظ', 'بنء', 'ماء', 'عكر', 'صيد', 'نحز', 'ارد', 'عظم', 'أطياف', 'ألو', 'كوط', 'نحب', 'نفد', 'مهج', 'ولم', 'يكن', 'يوم', 'اهل', 'غزة', 'لسط', 'سند', 'لكل', 'جرح', 'عرب', 'هتف', 'عظم', 'لمس', 'شغف', 'قلب', 'رقص', 'بهج', 'رغم', 'اصو', 'غرب', 'عدد', 'كانت', 'تبث', 'ودو', 'شؤم', 'طلب', 'إلغاء', 'برا', 'ظرف', 'عصب', 'نمر', 'لأن', 'تخف', 'قلب', 'برا', 'عرك', 'دق', 'خشم', 'كسر', 'عظم', 'وطح', 'رؤس', 'لكن', 'اكن', 'اخف', 'وجه', 'لأن', 'وثق', 'تان', 'وقة', 'سبح', 'وطن', 'لدي', 'سبح', 'طعم', 'فضة', 'عمر', 'عما', 'ذكر', 'طيب', 'نفس', 'لكن', 'حبذ', 'ظهر', 'لأن', 'خشى', 'عليها', 'فرط', 'ادب', 'سمح', 'الل', 'لأن', 'تقف', 'احد', 'يمد', 'يده', 'شعر', 'أخذ', 'أمل', 'دعب', 'شراشيب', 'فحص', 'حجر', 'سأل', 'كانت', 'يرز', 'تهز', 'رأس', 'ؤكد', 'يكر', 'عليها', 'مرت', 'غفل', 'يدس', 'جيب', 'يمض', 'سوق', 'شعب', 'كنت', 'ردد', 'بعة', 'سبح', 'غدد', 'سأل', 'أستفسر', 'شرد', 'كدت', 'اصر', 'خبر', 'أنواع', 'قدر', 'عرف', 'يقت', 'دلس', 'يرز', 'زبرجد', 'وكل', 'حجر', 'كرم', 'وأن', 'فصل', 'الن', 'طبع', 'صنع', 'كانت', 'دقة', 'صنع', 'أمز', 'سبح', 'تفح', 'عطر', 'فرك', 'حجر', 'رحت', 'أقدر', 'قيم', 'وثم', 'سوق', 'قال', 'بئع', 'مسن', 'تغض', 'وجه', 'وقر', 'سبح', 'خيط', 'نقي', 'خيط', 'سبح', 'يكون', 'قوا', 'فئد', 'سبح', 'قطع', 'دور', 'جوب', 'لهذ', 'دعم', 'سبح', 'بخط', 'تين', 'عدة', 'لتف', 'حجر', 'سبح', 'وقم', 'حبت', 'ألو', 'فقط', 'لتف', 'خيط', 'نظم', 'حبت', 'فهو', 'تور', 'خفي', 'ظار', 'لكن', 'وجد', 'نحس', 'قطع', 'عند', 'سبح', 'تعد', 'سبح', 'عقد', 'يعد', 'عقد', 'جرد', 'حبت', 'ناثر', 'تطؤ', 'قدم', 'عفر', 'ترب', 'يكون', 'خيط', 'سبح', 'ضعف', 'يحق', 'تخف', 'عليها', 'تكون', 'وثق', 'قوة', 'خيط', 'ومت', 'أصل', 'لأن', 'جوهر', 'بقى', 'نبه', 'يد', 'غرباء', 'خطف', 'منك', 'غفل', 'تدس', 'جيب']

# %%
lemmatized_word = [lemmatizer.lemmatize(word) for word in Filtered_text]
print("\nLemmatized Words:")
print(lemmatized_word)
# Out:
# Lemmatized Words:
# ['شعر', 'خسار', 'مرير', 'لأنني', 'كنى', 'جمهور', 'مباراة', 'كرة', 'قدم', 'جميل', 'جمع', 'أيام', 'فريق', 'عريق', 'فيصل', 'وحد', 'كنت', 'كسب', 'أنة', 'كنت', 'مع', 'صوت', 'صادح', 'واحد', 'موحد', 'هتاف', 'بليغ', 'قوة', 'أغاظ', 'أغاظ', 'بناء', 'ماء', 'عكر', 'صياد', 'انحاز', 'أردن', 'عظيم', 'أطياف', 'ألوان', 'وطن', 'نحب', 'فدى', 'مهج', 'لم', 'كنى', 'يوم', 'هل', 'غزة', 'فلسطين', 'سند', 'كل', 'جرح', 'عرب', 'هتاف', 'عظيم', 'لامس', 'شغاف', 'قلب', 'رقص', 'بهج', 'رغم', 'أصوات', 'غراب', 'عديد', 'كانت', 'باث', 'سوداوي', 'شؤم', 'مطالب', 'إلغاء', 'مباراة', 'ظرف', 'عصيب', 'نمر', 'أن', 'تخوف', 'انقلاب', 'مباراة', 'معركة', 'دق', 'خشوم', 'كسر', 'عظم', 'طحن', 'رؤوس', 'كنة', 'كنى', 'أخافي', 'مواجه', 'لأنني', 'واثق', 'متان', 'قوة', 'مسبح', 'وطن', 'لد', 'مسبح', 'مطعم', 'فض', 'عمر', 'عام', 'ذكر', 'طيب', 'نفس', 'كنة', 'حبذ', 'ظهر', 'أنة', 'خشى', 'على', 'انفراط', 'أدب', 'سمح', 'الله', 'أن', 'تقفي', 'أحد', 'أمد', 'يد', 'شعور', 'أخذ', 'تأمل', 'داعب', 'شراشيبها', 'تفحص', 'حجار', 'سأل', 'كانت', 'فيروز', 'هز', 'رأس', 'مؤكد', 'أكرى', 'على', 'مر', 'ويغافلك', 'داس', 'جيب', 'مضى', 'سوق', 'شعب', 'كنت', 'تردد', 'باع', 'مسابح', 'بغداد', 'سأل', 'استفسر', 'شارد', 'كاد', 'صار', 'خبير', 'أنواع', 'قادر', 'أعرف', 'ياقوت', 'السندلس', 'فيروز', 'زبرجد', 'كل', 'أحجار', 'كريم', 'أن', 'صل', 'الألون', 'طبيعة', 'صناع', 'كانت', 'دقة', 'صنع', 'ماز', 'مسابح', 'فاح', 'عطر', 'فرك', 'حجار', 'راحتيك', 'أقدر', 'قيم', 'ثمن', 'سوق', 'قال', 'بائع', 'مسن', 'متغضن', 'وجه', 'قور', 'مسبح', 'خيط', 'انتقى', 'خيط', 'مسبح', 'كوى', 'قوى', 'فائدة', 'مسبح', 'انقطع', 'دور', 'جاب', 'هذ', 'دعم', 'مسبح', 'خيط', 'متين', 'عادة', 'التفت', 'حجار', 'مسبح', 'قيم', 'حب', 'ألوان', 'فقط', 'التفت', 'خيط', 'نظم', 'حب', 'هو', 'متواري', 'مخفي', 'أنظار', 'لكن', 'موجود', 'نحس', 'انقطع', 'عند', 'مسبح', 'تعود', 'مسبح', 'عقد', 'عاد', 'عقد', 'مجرد', 'حب', 'متناثر', 'تطؤها', 'أقدام', 'عفر', 'تراب', 'كوى', 'خيط', 'مسبح', 'ضعيف', 'أحاق', 'أخاف', 'على', 'تكون', 'واثق', 'قوة', 'خيط', 'متان', 'أصالة', 'أن', 'جوهر', 'بقى', 'انتاب', 'يد', 'غرباء', 'تخطف', 'من', 'تغافل', 'داس', 'جيب']

# %% [markdown]
# #### Comparing IRISTEMMER and Qalsadi Lemmatizer Results:
#
# Here's a comparison of the stemming and lemmatization results you provided:
#
# Similarities:
#
#     Both techniques aim to reduce words to their base or root form.
#
#     Both methods successfully handled most of the words, reducing them to recognizable roots.
#
#     Both outputs maintain the general flow and meaning of the original text.
#
# Differences:
#
#     Output Form:
#
#         IRISTEMMER: Produces stems, which may not always be actual words but are linguistic roots.
#
#         Qalsadi: Produces lemmas, which are actual words in the language.
#
#     Word Accuracy:
#
#         IRISTEMMER: May produce less accurate representations, especially for irregular words.
#
#         Qalsadi: Generally provides more accurate lemmas due to its dictionary-based approach and understanding of Arabic morphology.
#
#     Word Length:
#
#         IRISTEMMER: Often creates shorter forms as it focuses on stripping suffixes.
#
#         Qalsadi: May retain some suffixes or prefixes depending on the word and its grammatical role.
#
# Examples:
#
#     "شعرت" (felt):
#
#         IRISTEMMER: "شعر" (hair, poetry) - Less accurate, loses the meaning of feeling.
#
#         Qalsadi: "شعر" (felt) - Maintains the correct meaning and is a valid word.
#
#     "جمهور" (audience):
#
#         IRISTEMMER: "جمهور" (republic) - Stem is accurate but has a different meaning.
#
#         Qalsadi: "جمهور" (audience) - Correct lemma with the intended meaning.

# %% [markdown]
# # Perform Part-Of-Speech tagging

# %% [markdown]
# ### Perform Parts of Speech technics based on Rule based approach

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

#Filtered data to a single string
data  = ' '.join(Filtered_text)

#process with SpaCy nlp
content = nlp(data)

for word in content:
    #word     #word with process of pos  #word with process of pos+explanation
    print(word , "//",word.pos_  , "//" ,spacy.explain(word.pos_))
# Out:
# شعرت // PROPN // proper noun
# بخسارة // PROPN // proper noun
# مريرة // PROPN // proper noun
# لأنني // PROPN // proper noun
# أكن // PROPN // proper noun
# جمهور // PROPN // proper noun
# مباراة // PROPN // proper noun
# كرة // PROPN // proper noun
# القدم // PROPN // proper noun
# الجميلة // PROPN // proper noun
# جمعت // PROPN // proper noun
# أيام // PROPN // proper noun
# الفريقين // PROPN // proper noun
# العريقين // PROPN // proper noun
# الفيصلي // PROPN // proper noun
# والوحدات // PROPN // proper noun
# كنت // PROPN // proper noun
# سأكسب // PROPN // proper noun
# أني // PROPN // proper noun
# كنت // PROPN // proper noun
# معهم // PROPN // proper noun
# صوتا // NOUN // noun
# صادحا // PROPN // proper noun
# واحدا // PROPN // proper noun
# موحدا // PROPN // proper noun
# هتاف // PROPN // proper noun
# بليغ // PROPN // proper noun
# قوي // PROPN // proper noun
# أغاظ // PROPN // proper noun
# ويغيظ // PROPN // proper noun
# أبناء // PROPN // proper noun
# الماء // PROPN // proper noun
# العكر // PROPN // proper noun
# وصياديه // PROPN // proper noun
# وينحاز // PROPN // proper noun
# أردن // PROPN // proper noun
# عظيم // PROPN // proper noun
# بأطيافه // PROPN // proper noun
# وألوانه // PROPN // proper noun
# كوطن // PROPN // proper noun
# نحبه // PROPN // proper noun
# ونفديه // PROPN // proper noun
# بالمهج // PROPN // proper noun
# ولم // PROPN // proper noun
# يكن // PROPN // proper noun
# يوما // VERB // verb
# أهله // PROPN // proper noun
# غزة // PROPN // proper noun
# وفلسطين // PROPN // proper noun
# وسندا // PROPN // proper noun
# لكل // PROPN // proper noun
# جرح // PROPN // proper noun
# عربي // PROPN // proper noun
# الهتافات // PROPN // proper noun
# العظيمة // PROPN // proper noun
# لامست // PROPN // proper noun
# شغاف // PROPN // proper noun
# قلبي // PROPN // proper noun
# ورقصتني // PROPN // proper noun
# بهجة // PROPN // proper noun
# فرغم // PROPN // proper noun
# أصوات // NOUN // noun
# غرابية // NOUN // noun
# عديدة // NOUN // noun
# كانت // PROPN // proper noun
# تبث // VERB // verb
# سوداويتها // PROPN // proper noun
# وشؤمها // PROPN // proper noun
# مطالبة // PROPN // proper noun
# بإلغاء // PROPN // proper noun
# المباراة // PROPN // proper noun
# الظرف // PROPN // proper noun
# العصيب // PROPN // proper noun
# نمر // PROPN // proper noun
# لأنهم // PROPN // proper noun
# يتخوفون // PROPN // proper noun
# انقلاب // PROPN // proper noun
# المباراة // PROPN // proper noun
# معركة // VERB // verb
# دق // PROPN // proper noun
# خشوم // PROPN // proper noun
# كسر // PROPN // proper noun
# عظم // PROPN // proper noun
# وطحن // PROPN // proper noun
# رؤوس // PROPN // proper noun
# لكني // PROPN // proper noun
# أكن // PROPN // proper noun
# أخاف // PROPN // proper noun
# المواجهة // PROPN // proper noun
# لأنني // PROPN // proper noun
# واثق // PROPN // proper noun
# متانة // ADJ // adjective
# وقوة // NOUN // noun
# مسبحتنا // NOUN // noun
# الوطنية // PROPN // proper noun
# لدي // PROPN // proper noun
# مسبحة // PROPN // proper noun
# مطعمة // PROPN // proper noun
# بالفضة // PROPN // proper noun
# عمرها // PROPN // proper noun
# عاما // PROPN // proper noun
# ذكريات // PROPN // proper noun
# طيبة // PROPN // proper noun
# نفسي // PROPN // proper noun
# لكني // PROPN // proper noun
# أحبذ // PROPN // proper noun
# أظهرها // PROPN // proper noun
# لأني // PROPN // proper noun
# أخشى // VERB // verb
# عليها // PROPN // proper noun
# الانفراط // PROPN // proper noun
# أدبك // PROPN // proper noun
# سمح // PROPN // proper noun
# الله // PROPN // proper noun
# لأنك // NOUN // noun
# تقف // PROPN // proper noun
# أحدهم // PROPN // proper noun
# فيمد // PROPN // proper noun
# يده // PROPN // proper noun
# شعوريا // PROPN // proper noun
# ويأخذها // PROPN // proper noun
# يتأملها // PROPN // proper noun
# ويداعب // PROPN // proper noun
# شراشيبها // PROPN // proper noun
# ويتفحص // PROPN // proper noun
# حجارتها // PROPN // proper noun
# ويسألك // PROPN // proper noun
# كانت // PROPN // proper noun
# فيروزا // PROPN // proper noun
# فتهز // PROPN // proper noun
# رأسك // PROPN // proper noun
# مؤكدا // PROPN // proper noun
# يكر // PROPN // proper noun
# عليها // NOUN // noun
# مرتين // PROPN // proper noun
# ويغافلك // NOUN // noun
# ويدسها // PROPN // proper noun
# جيبه // PROPN // proper noun
# ويمضي // PROPN // proper noun
# سوق // PROPN // proper noun
# شعبية // PROPN // proper noun
# كنت // PROPN // proper noun
# أتردد // PROPN // proper noun
# باعة // VERB // verb
# المسابح // PROPN // proper noun
# بغداد // PROPN // proper noun
# أسأل // VERB // verb
# وأستفسر // PROPN // proper noun
# شاردة // PROPN // proper noun
# كدت // PROPN // proper noun
# أصير // PROPN // proper noun
# خبيرا // PROPN // proper noun
# بأنواعها // PROPN // proper noun
# قادرا // PROPN // proper noun
# أعرف // PROPN // proper noun
# الياقوت // PROPN // proper noun
# السندلس // PROPN // proper noun
# الفيروز // PROPN // proper noun
# والزبرجد // PROPN // proper noun
# وكل // PROPN // proper noun
# الأحجار // INTJ // interjection
# الكريمة // VERB // verb
# وأن // PROPN // proper noun
# أفصل // NOUN // noun
# الألون // PROPN // proper noun
# الطبيعية // PROPN // proper noun
# الصناعية // PROPN // proper noun
# كانت // PROPN // proper noun
# دقة // VERB // verb
# صنعها // PROPN // proper noun
# وأميز // PROPN // proper noun
# المسابح // PROPN // proper noun
# تفوح // PROPN // proper noun
# عطرا // PROPN // proper noun
# فركت // PROPN // proper noun
# حجارتها // PROPN // proper noun
# راحتيك // PROPN // proper noun
# وأقدر // PROPN // proper noun
# قيمتها // PROPN // proper noun
# وثمنها // PROPN // proper noun
# السوق // PROPN // proper noun
# قال // PROPN // proper noun
# بائع // NOUN // noun
# مسن // NOUN // noun
# متغضن // NOUN // noun
# الوجه // PROPN // proper noun
# وقور // PROPN // proper noun
# المسبحة // PROPN // proper noun
# خيط // PROPN // proper noun
# تنتقي // PROPN // proper noun
# خيطا // PROPN // proper noun
# لمسبحتك // PROPN // proper noun
# يكون // VERB // verb
# قويا // PROPN // proper noun
# فائدة // PROPN // proper noun
# مسبحة // PROPN // proper noun
# تنقطع // PROPN // proper noun
# دورة // PROPN // proper noun
# جوبي // PROPN // proper noun
# ولهذا // PROPN // proper noun
# دعمت // PROPN // proper noun
# مسبحتي // NOUN // noun
# بخيط // PROPN // proper noun
# متين // PROPN // proper noun
# العادة // PROPN // proper noun
# نلتفت // PROPN // proper noun
# حجارة // PROPN // proper noun
# المسبحة // PROPN // proper noun
# وقيمة // PROPN // proper noun
# حباتها // PROPN // proper noun
# وألوانها // PROPN // proper noun
# فقط // PROPN // proper noun
# نلتفت // PROPN // proper noun
# الخيط // PROPN // proper noun
# ينظم // PROPN // proper noun
# الحبات // PROPN // proper noun
# فهو // PROPN // proper noun
# متوار // PROPN // proper noun
# مخفي // PROPN // proper noun
# الأنظار // PROPN // proper noun
# لكنه // PROPN // proper noun
# موجود // PROPN // proper noun
# نحس // PROPN // proper noun
# ينقطع // PROPN // proper noun
# وعندها // PROPN // proper noun
# المسبحة // PROPN // proper noun
# تعود // PROPN // proper noun
# مسبحة // PROPN // proper noun
# والعقد // PROPN // proper noun
# يعود // PROPN // proper noun
# عقدا // PROPN // proper noun
# مجرد // PROPN // proper noun
# حبات // PROPN // proper noun
# متناثرة // VERB // verb
# تطؤها // PROPN // proper noun
# الأقدام // PROPN // proper noun
# ويعفرها // PROPN // proper noun
# التراب // PROPN // proper noun
# يكون // PROPN // proper noun
# خيط // AUX // auxiliary
# مسبحتك // VERB // verb
# ضعيفا // ADJ // adjective
# يحق // NOUN // noun
# تخاف // PROPN // proper noun
# عليها // PROPN // proper noun
# تكون // NOUN // noun
# واثقا // VERB // verb
# قوة // PROPN // proper noun
# الخيط // VERB // verb
# ومتانته // ADJ // adjective
# وأصالته // ADJ // adjective
# لأنه // PROPN // proper noun
# الجوهر // PROPN // proper noun
# يبقى // PROPN // proper noun
# تنتبه // PROPN // proper noun
# يد // PROPN // proper noun
# الغرباء // PROPN // proper noun
# تخطفها // PROPN // proper noun
# منك // PROPN // proper noun
# وتغافلك // PROPN // proper noun
# وتدسها // PROPN // proper noun
# جيبها // NOUN // noun

# %% [markdown]
# ## So as we see in the result is not good and not bad for SpaCy POS tagger

# %% [markdown]
# ### Perform Parts of Speech technics based Machine learning approaches with model arabic.tagger

# %%
from nltk.tag import StanfordPOSTagger

# Set the absolute paths to the Stanford POS Tagger jar file and model file
jar_path = '/home/hafdaoui/stanford-tagger-4.2.0/stanford-postagger-full-2020-11-17/stanford-postagger.jar'
model_path = '/home/hafdaoui/stanford-tagger-4.2.0/stanford-postagger-full-2020-11-17/models/arabic.tagger'

tagger = StanfordPOSTagger(model_path, jar_path)

# Tag the tokens
tagged_tokens = tagger.tag(Filtered_text)

# Print the tagged tokens
print(tagged_tokens)
# Out:
# [('', 'شعرت/VBD'), ('', 'بخسارة/NN'), ('', 'مريرة/JJ'), ('', 'لأنني/JJ'), ('', 'أكن/VBD'), ('', 'جمهور/NN'), ('', 'مباراة/NN'), ('', 'كرة/NN'), ('', 'القدم/DTNN'), ('', 'الجميلة/DTJJ'), ('', 'جمعت/VBD'), ('', 'أيام/NN'), ('', 'الفريقين/DTNNS'), ('', 'العريقين/DTJJ'), ('', 'الفيصلي/DTNNP'), ('', 'والوحدات/NNS'), ('', 'كنت/VBD'), ('', 'سأكسب/NN'), ('', 'أني/JJ'), ('', 'كنت/VBD'), ('', 'معهم/NN'), ('', 'صوتا/NN'), ('', 'صادحا/JJ'), ('', 'واحدا/JJ'), ('', 'موحدا/JJ'), ('', 'هتاف/NN'), ('', 'بليغ/NN'), ('', 'قوي/JJ'), ('', 'أغاظ/VBD'), ('', 'ويغيظ/NNP'), ('', 'أبناء/VBG'), ('', 'الماء/DTNN'), ('', 'العكر/DTNN'), ('', 'وصياديه/NNP'), ('', 'وينحاز/NNP'), ('', 'أردن/NN'), ('', 'عظيم/JJ'), ('', 'بأطيافه/NN'), ('', 'وألوانه/NNP'), ('', 'كوطن/NNP'), ('', 'نحبه/VBP'), ('', 'ونفديه/NNP'), ('', 'بالمهج/NNP'), ('', 'ولم/NNP'), ('', 'يكن/VBP'), ('', 'يوما/NN'), ('', 'أهله/NN'), ('', 'غزة/NNP'), ('', 'وفلسطين/NNP'), ('', 'وسندا/NNP'), ('', 'لكل/VBD'), ('', 'جرح/NN'), ('', 'عربي/JJ'), ('', 'الهتافات/DTNNS'), ('', 'العظيمة/DTJJ'), ('', 'لامست/VBD'), ('', 'شغاف/NN'), ('', 'قلبي/JJ'), ('', 'ورقصتني/JJ'), ('', 'بهجة/NN'), ('', 'فرغم/NN'), ('', 'أصوات/NNS'), ('', 'غرابية/JJ'), ('', 'عديدة/JJ'), ('', 'كانت/VBD'), ('', 'تبث/VBP'), ('', 'سوداويتها/NN'), ('', 'وشؤمها/NN'), ('', 'مطالبة/NN'), ('', 'بإلغاء/NN'), ('', 'المباراة/DTNN'), ('', 'الظرف/DTNN'), ('', 'العصيب/DTJJ'), ('', 'نمر/NNP'), ('', 'لأنهم/NNP'), ('', 'يتخوفون/VBP'), ('', 'انقلاب/NN'), ('', 'المباراة/DTNN'), ('', 'معركة/NN'), ('', 'دق/NN'), ('', 'خشوم/NN'), ('', 'كسر/NN'), ('', 'عظم/NN'), ('', 'وطحن/NN'), ('', 'رؤوس/NN'), ('', 'لكني/JJ'), ('', 'أكن/VBD'), ('', 'أخاف/NN'), ('', 'المواجهة/DTNN'), ('', 'لأنني/NNS'), ('', 'واثق/JJ'), ('', 'متانة/NN'), ('', 'وقوة/NN'), ('', 'مسبحتنا/JJ'), ('', 'الوطنية/DTJJ'), ('', 'لدي/NN'), ('', 'مسبحة/JJ'), ('', 'مطعمة/JJ'), ('', 'بالفضة/JJ'), ('', 'عمرها/NN'), ('', 'عاما/NN'), ('', 'ذكريات/NNS'), ('', 'طيبة/JJ'), ('', 'نفسي/VBP'), ('', 'لكني/NNP'), ('', 'أحبذ/VBD'), ('', 'أظهرها/NN'), ('', 'لأني/JJ'), ('', 'أخشى/VBD'), ('', 'عليها/NN'), ('', 'الانفراط/DTNN'), ('', 'أدبك/NNP'), ('', 'سمح/VBD'), ('', 'الله/NNP'), ('', 'لأنك/VBD'), ('', 'تقف/VBP'), ('', 'أحدهم/NN'), ('', 'فيمد/NNP'), ('', 'يده/VBP'), ('', 'شعوريا/NN'), ('', 'ويأخذها/NN'), ('', 'يتأملها/VBP'), ('', 'ويداعب/NNP'), ('', 'شراشيبها/NN'), ('', 'ويتفحص/NN'), ('', 'حجارتها/NN'), ('', 'ويسألك/NNP'), ('', 'كانت/VBD'), ('', 'فيروزا/NNP'), ('', 'فتهز/NNP'), ('', 'رأسك/NNP'), ('', 'مؤكدا/VN'), ('', 'يكر/VBP'), ('', 'عليها/NN'), ('', 'مرتين/NNS'), ('', 'ويغافلك/NNP'), ('', 'ويدسها/NNP'), ('', 'جيبه/NNP'), ('', 'ويمضي/NNP'), ('', 'سوق/NN'), ('', 'شعبية/JJ'), ('', 'كنت/VBD'), ('', 'أتردد/NN'), ('', 'باعة/NN'), ('', 'المسابح/DTNN'), ('', 'بغداد/NNP'), ('', 'أسأل/NN'), ('', 'وأستفسر/NN'), ('', 'شاردة/NN'), ('', 'كدت/VBD'), ('', 'أصير/NN'), ('', 'خبيرا/NN'), ('', 'بأنواعها/NN'), ('', 'قادرا/JJ'), ('', 'أعرف/NN'), ('', 'الياقوت/DTNN'), ('', 'السندلس/DTJJ'), ('', 'الفيروز/DTNN'), ('', 'والزبرجد/NN'), ('', 'وكل/NN'), ('', 'الأحجار/DTNN'), ('', 'الكريمة/DTJJ'), ('', 'وأن/VBD'), ('', 'أفصل/NN'), ('', 'الألون/DTNNS'), ('', 'الطبيعية/DTJJ'), ('', 'الصناعية/DTJJ'), ('', 'كانت/VBD'), ('', 'دقة/NN'), ('', 'صنعها/NN'), ('', 'وأميز/NN'), ('', 'المسابح/DTNN'), ('', 'تفوح/VBP'), ('', 'عطرا/NN'), ('', 'فركت/NNP'), ('', 'حجارتها/NNP'), ('', 'راحتيك/NNP'), ('', 'وأقدر/NNP'), ('', 'قيمتها/NN'), ('', 'وثمنها/NN'), ('', 'السوق/DTNN'), ('', 'قال/VBD'), ('', 'بائع/NNP'), ('', 'مسن/NNP'), ('', 'متغضن/JJ'), ('', 'الوجه/DTNN'), ('', 'وقور/NN'), ('', 'المسبحة/DTNN'), ('', 'خيط/NN'), ('', 'تنتقي/VBP'), ('', 'خيطا/NN'), ('', 'لمسبحتك/NNP'), ('', 'يكون/VBP'), ('', 'قويا/JJ'), ('', 'فائدة/NN'), ('', 'مسبحة/JJ'), ('', 'تنقطع/VBP'), ('', 'دورة/NN'), ('', 'جوبي/NNP'), ('', 'ولهذا/NNP'), ('', 'دعمت/VBD'), ('', 'مسبحتي/NNS'), ('', 'بخيط/NN'), ('', 'متين/JJ'), ('', 'العادة/DTNN'), ('', 'نلتفت/VBP'), ('', 'حجارة/NN'), ('', 'المسبحة/DTNN'), ('', 'وقيمة/NN'), ('', 'حباتها/NN'), ('', 'وألوانها/NN'), ('', 'فقط/RB'), ('', 'نلتفت/VBP'), ('', 'الخيط/DTNN'), ...

# %% [markdown]
# ## but the  Stanford Arabic POS Tagger work so good and we get wonderful result

# %% [markdown]
# # Comparing SpaCy Rule-Based and Stanford Tagger Machine Learning POS Tagging:
#
# Here's a comparison of the POS tagging results you obtained using SpaCy's rule-based approach and the Stanford Tagger's machine learning model:
#
# General Observations:
#
#     SpaCy with en_core_web_sm:
#
#         Incorrectly identifies most words as proper nouns (PROPN). This suggests a mismatch between the language model and your Arabic text.
#
#         Limited accuracy due to the model's inability to handle Arabic morphology and context.
#
#     Stanford Tagger with Arabic Model:
#
#         Demonstrates much better performance, correctly identifying various parts of speech including nouns (NN), verbs (VBD, VBP), adjectives (JJ), and more.
#
#         Leverages machine learning for better accuracy and understanding of Arabic grammatical structure.

# %% [markdown]
# # NAMED ENTITE RECOGNITION

# %%
import stanza
nlp = stanza.Pipeline('ar', processors='tokenize,ner') # initialize English neural pipeline
doc = nlp(cleaned_) # run annotation over a sentence
for entity in doc.ents:
    print(f"Entity: {entity.text}\t Type: {entity.type}")
# Out:
# 2024-04-08 02:05:21 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-04-08 02:05:22 INFO: Downloaded file to /home/hafdaoui/stanza_resources/resources.json
# 2024-04-08 02:05:22 WARNING: Language ar package default expects mwt, which has been added
# 2024-04-08 02:05:22 INFO: Loading these models for language: ar (Arabic):
# ============================
# | Processor | Package      |
# ----------------------------
# | tokenize  | padt         |
# | mwt       | padt         |
# | ner       | aqmar_charlm |
# ============================
#
# 2024-04-08 02:05:22 INFO: Using device: cpu
# 2024-04-08 02:05:22 INFO: Loading: tokenize
# 2024-04-08 02:05:22 INFO: Loading: mwt
# 2024-04-08 02:05:22 INFO: Loading: ner
# 2024-04-08 02:05:23 INFO: Done loading processors!
# Entity: غزة	 Type: LOC
# Entity: وفلسطين	 Type: LOC
# Entity: بغداد	 Type: LOC

# %%
print(doc)
print(doc.entities)
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "شعرت",
#       "start_char": 0,
#       "end_char": 4,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         2,
#         3
#       ],
#       "text": "بخسارة",
#       "start_char": 5,
#       "end_char": 11,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "ب"
#     },
#     {
#       "id": 3,
#       "text": "خسارة"
#     },
#     {
#       "id": 4,
#       "text": "مريرة",
#       "start_char": 12,
#       "end_char": 17,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         5,
#         6
#       ],
#       "text": "لأنني",
#       "start_char": 18,
#       "end_char": 23,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "لأن"
#     },
#     {
#       "id": 6,
#       "text": "ني"
#     },
#     {
#       "id": 7,
#       "text": "لم",
#       "start_char": 24,
#       "end_char": 26,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "أكن",
#       "start_char": 27,
#       "end_char": 30,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 9,
#       "text": "بين",
#       "start_char": 31,
#       "end_char": 34,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 10,
#       "text": "جمهور",
#       "start_char": 35,
#       "end_char": 40,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 11,
#       "text": "مباراة",
#       "start_char": 41,
#       "end_char": 47,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 12,
#       "text": "كرة",
#       "start_char": 48,
#       "end_char": 51,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 13,
#       "text": "القدم",
#       "start_char": 52,
#       "end_char": 57,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 14,
#       "text": "الجميلة",
#       "start_char": 58,
#       "end_char": 65,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 15,
#       "text": "التي",
#       "start_char": 66,
#       "end_char": 70,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 16,
#       "text": "جمعت",
#       "start_char": 71,
#       "end_char": 75,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 17,
#       "text": "قبل",
#       "start_char": 76,
#       "end_char": 79,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 18,
#       "text": "أيام",
#       "start_char": 80,
#       "end_char": 84,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 19,
#       "text": "الفريقين",
#       "start_char": 85,
#       "end_char": 93,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 20,
#       "text": "العريقين",
#       "start_char": 94,
#       "end_char": 102,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 21,
#       "text": "الفيصلي",
#       "start_char": 103,
#       "end_char": 110,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         22,
#         23
#       ],
#       "text": "والوحدات",
#       "start_char": 111,
#       "end_char": 119,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 22,
#       "text": "و"
#     },
#     {
#       "id": 23,
#       "text": "الوحدات"
#     },
#     {
#       "id": 24,
#       "text": "كم",
#       "start_char": 120,
#       "end_char": 122,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 25,
#       "text": "كنت",
#       "start_char": 123,
#       "end_char": 126,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         26,
#         27
#       ],
#       "text": "سأكسب",
#       "start_char": 127,
#       "end_char": 132,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 26,
#       "text": "س"
#     },
#     {
#       "id": 27,
#       "text": "أكسب"
#     },
#     {
#       "id": 28,
#       "text": "لو",
#       "start_char": 133,
#       "end_char": 135,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 29,
#       "text": "أني",
#       "start_char": 136,
#       "end_char": 139,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 30,
#       "text": "كنت",
#       "start_char": 140,
#       "end_char": 143,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         31,
#         32
#       ],
#       "text": "معهم",
#       "start_char": 144,
#       "end_char": 148,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 31,
#       "text": "مع"
#     },
#     {
#       "id": 32,
#       "text": "هم"
#     },
#     {
#       "id": 33,
#       "text": "صوتا",
#       "start_char": 149,
#       "end_char": 153,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 34,
#       "text": "صادحا",
#       "start_char": 154,
#       "end_char": 159,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 35,
#       "text": "واحدا",
#       "start_char": 160,
#       "end_char": 165,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 36,
#       "text": "موحدا",
#       "start_char": 166,
#       "end_char": 171,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 37,
#       "text": "في",
#       "start_char": 172,
#       "end_char": 174,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 38,
#       "text": "هتاف",
#       "start_char": 175,
#       "end_char": 179,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 39,
#       "text": "بليغ",
#       "start_char": 180,
#       "end_char": 184,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 40,
#       "text": "قوي",
#       "start_char": 185,
#       "end_char": 188,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 41,
#       "text": "أغاظ",
#       "start_char": 189,
#       "end_char": 193,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         42,
#         43
#       ],
#       "text": "ويغيظ",
#       "start_char": 194,
#       "end_char": 199,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 42,
#       "text": "و"
#     },
#     {
#       "id": 43,
#       "text": "يغيظ"
#     },
#     {
#       "id": 44,
#       "text": "أبناء",
#       "start_char": 200,
#       "end_char": 205,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 45,
#       "text": "الماء",
#       "start_char": 206,
#       "end_char": 211,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 46,
#       "text": "العكر",
#       "start_char": 212,
#       "end_char": 217,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         47,
#         49
#       ],
#       "text": "وصياديه",
#       "start_char": 218,
#       "end_char": 225,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 47,
#       "text": "و"
#     },
#     {
#       "id": 48,
#       "text": "صيادي"
#     },
#     {
#       "id": 49,
#       "text": "ه"
#     },
#     {
#       "id": [
#         50,
#         51
#       ],
#       "text": "وينحاز",
#       "start_char": 226,
#       "end_char": 232,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 50,
#       "text": "و"
#     },
#     {
#       "id": 51,
#       "text": "ينحاز"
#     },
#     {
#       "id": 52,
#       "text": "إلى",
#       "start_char": 233,
#       "end_char": 236,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 53,
#       "text": "أردن",
#       "start_char": 237,
#       "end_char": 241,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 54,
#       "text": "عظيم",
#       "start_char": 242,
#       "end_char": 246,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         55,
#         57
#       ],
#       "text": "بأطيافه",
#       "start_char": 247,
#       "end_char": 254,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 55,
#       "text": "ب"
#     },
#     {
#       "id": 56,
#       "text": "أطياف"
#     },
#     {
#       "id": 57,
#       "text": "ه"
#     },
#     {
#       "id": [
#         58,
#         60
#       ],
#       "text": "وألوانه",
#       "start_char": 255,
#       "end_char": 262,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 58,
#       "text": "و"
#     },
#     {
#       "id": 59,
#       "text": "ألوان"
#     },
#     {
#       "id": 60,
#       "text": "ه"
#     },
#     {
#       "id": 61,
#       "text": "كوطن",
#       "start_char": 263,
#       "end_char": 267,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         62,
#         63
#       ],
#       "text": "نحبه",
#       "start_char": 268,
#       "end_char": 272,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 62,
#       "text": "نحب"
#     },
#     {
#       "id": 63,
#       "text": "ه"
#     },
#     {
#       "id": [
#         64,
#         66
#       ],
#       "text": "ونفديه",
#       "start_char": 273,
#       "end_char": 279,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 64,
#       "text": "و"
#     },
#     {
#       "id": 65,
#       "text": "نفدي"
#     },
#     {
#       "id": 66,
#       "text": "ه"
#     },
#     {
#       "id": [
#         67,
#         68
#       ],
#       "text": "بالمهج",
#       "start_char": 280,
#       "end_char": 286,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 67,
#       "text": "ب"
#     },
#     {
#       "id": 68,
#       "text": "المهج"
#     },
#     {
#       "id": [
#         69,
#         70
#       ],
#       "text": "ولم",
#       "start_char": 287,
#       "end_char": 290,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 69,
#       "text": "و"
#     },
#     {
#       "id": 70,
#       "text": "لم"
#     },
#     {
#       "id": 71,
#       "text": "يكن",
#       "start_char": 291,
#       "end_char": 294,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 72,
#       "text": "يوما",
#       "start_char": 295,
#       "end_char": 299,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 73,
#       "text": "إلا",
#       "start_char": 300,
#       "end_char": 303,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 74,
#       "text": "مع",
#       "start_char": 304,
#       "end_char": 306,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         75,
#         76
#       ],
#       "text": "أهله",
#       "start_char": 307,
#       "end_char": 311,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 75,
#       "text": "أهل"
#     },
#     {
#       "id": 76,
#       "text": "ه"
#     },
#     {
#       "id": 77,
#       "text": "في",
#       "start_char": 312,
#       "end_char": 314,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 78,
#       "text": "غزة",
#       "start_char": 315,
#       "end_char": 318,
#       "ner": "S-LOC",
#       "multi_ner": [
#         "S-LOC"
#       ]
#     },
#     {
#       "id": [
#         79,
#         80
#       ],
#       "text": "وفلسطين",
#       "start_char": 319,
#       "end_char": 326,
#       "ner": "S-LOC",
#       "multi_ner": [
#         "S-LOC"
#       ]
#     },
#     {
#       "id": 79,
#       "text": "و"
#     },
#     {
#       "id": 80,
#       "text": "فلسطين"
#     },
#     {
#       "id": [
#         81,
#         82
#       ],
#       "text": "وسندا",
#       "start_char": 327,
#       "end_char": 332,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 81,
#       "text": "و"
#     },
#     {
#       "id": 82,
#       "text": "سندا"
#     },
#     {
#       "id": [
#         83,
#         84
#       ],
#       "text": "لكل",
#       "start_char": 333,
#       "end_char": 336,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 83,
#       "text": "ل"
#     },
#     {
#       "id": 84,
#       "text": "كل"
#     },
#     {
#       "id": 85,
#       "text": "جرح",
#       "start_char": 337,
#       "end_char": 340,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 86,
#       "text": "عربي",
#       "start_char": 341,
#       "end_char": 345,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 87,
#       "text": "الهتافات",
#       "start_char": 346,
#       "end_char": 354,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 88,
#       "text": "العظيمة",
#       "start_char": 355,
#       "end_char": 362,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         89,
#         90
#       ],
#       "text": "لامست",
#       "start_char": 363,
#       "end_char": 368,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 89,
#       "text": "ل"
#     },
#     {
#       "id": 90,
#       "text": "أمست"
#     },
#     {
#       "id": 91,
#       "text": "شغاف",
#       "start_char": 369,
#       "end_char": 373,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 92,
#       "text": "قلبي",
#       "start_char": 374,
#       "end_char": 378,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         93,
#         94
#       ],
#       "text": "ورقصتني",
#       "start_char": 379,
#       "end_char": 386,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 93,
#       "text": "و"
#     },
#     {
#       "id": 94,
#       "text": "رقصتني"
#     },
#     {
#       "id": [
#         95,
#         96
#       ],
#       "text": "بهجة",
#       "start_char": 387,
#       "end_char": 391,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 95,
#       "text": "ب"
#     },
#     {
#       "id": 96,
#       "text": "هجة"
#     },
#     {
#       "id": 97,
#       "text": "فرغم",
#       "start_char": 392,
#       "end_char": 396,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 98,
#       "text": "أن",
#       "start_char": 397,
#       "end_char": 399,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 99,
#       "text": "أصوات",
#       "start_char": 400,
#       "end_char": 405,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 100,
#       "text": "غرابية",
#       "start_char": 406,
#       "end_char": 412,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 101,
#       "text": "عديدة",
#       "start_char": 413,
#       "end_char": 418,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 102,
#       "text": "كانت",
#       "start_char": 419,
#       "end_char": 423,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 103,
#       "text": "تبث",
#       "start_char": 424,
#       "end_char": 427,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         104,
#         106
#       ],
#       "text": "سوداويتها",
#       "start_char": 428,
#       "end_char": 437,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 104,
#       "text": "س"
#     },
#     {
#       "id": 105,
#       "text": "وداوية"
#     },
#     {
#       "id": 106,
#       "text": "ها"
#     },
#     {
#       "id": [
#         107,
#         109
#       ],
#       "text": "وشؤمها",
#       "start_char": 438,
#       "end_char": 444,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 107,
#       "text": "و"
#     },
#     {
#       "id": 108,
#       "text": "شؤم"
#     },
#     {
#       "id": 109,
#       "text": "ها"
#     },
#     {
#       "id": 110,
#       "text": "مطالبة",
#       "start_char": 445,
#       "end_char": 451,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         111,
#         112
#       ],
#       "text": "بإلغاء",
#       "start_char": 452,
#       "end_char": 458,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 111,
#       "text": "ب"
#     },
#     {
#       "id": 112,
#       "text": "إلغاء"
#     },
#     {
#       "id": 113,
#       "text": "المباراة",
#       "start_char": 459,
#       "end_char": 467,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 114,
#       "text": "في",
#       "start_char": 468,
#       "end_char": 470,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 115,
#       "text": "الظرف",
#       "start_char": 471,
#       "end_char": 476,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 116,
#       "text": "العصيب",
#       "start_char": 477,
#       "end_char": 483,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 117,
#       "text": "الذي",
#       "start_char": 484,
#       "end_char": 488,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 118,
#       "text": "نمر",
#       "start_char": 489,
#       "end_char": 492,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         119,
#         120
#       ],
#       "text": "فيه",
#       "start_char": 493,
#       "end_char": 496,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 119,
#       "text": "في"
#     },
#     {
#       "id": 120,
#       "text": "ه"
#     },
#     {
#       "id": [
#         121,
#         122
#       ],
#       "text": "لأنهم",
#       "start_char": 497,
#       "end_char": 502,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 121,
#       "text": "لأن"
#     },
#     {
#       "id": 122,
#       "text": "هم"
#     },
#     {
#       "id": 123,
#       "text": "يتخوفون",
#       "start_char": 503,
#       "end_char": 510,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 124,
#       "text": "من",
#       "start_char": 511,
#       "end_char": 513,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 125,
#       "text": "انقلاب",
#       "start_char": 514,
#       "end_char": 520,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 126,
#       "text": "المباراة",
#       "start_char": 521,
#       "end_char": 529,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 127,
#       "text": "إلى",
#       "start_char": 530,
#       "end_char": 533,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 128,
#       "text": "معركة",
#       "start_char": 534,
#       "end_char": 539,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 129,
#       "text": "دق",
#       "start_char": 540,
#       "end_char": 542,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 130,
#       "text": "خشوم",
#       "start_char": 543,
#       "end_char": 547,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 131,
#       "text": "و",
#       "start_char": 548,
#       "end_char": 549,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 132,
#       "text": "كسر",
#       "start_char": 550,
#       "end_char": 553,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 133,
#       "text": "عظم",
#       "start_char": 554,
#       "end_char": 557,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         134,
#         135
#       ],
#       "text": "وطحن",
#       "start_char": 558,
#       "end_char": 562,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 134,
#       "text": "و"
#     },
#     {
#       "id": 135,
#       "text": "طحن"
#     },
#     {
#       "id": 136,
#       "text": "رؤوس",
#       "start_char": 563,
#       "end_char": 567,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 137,
#       "text": "لكني",
#       "start_char": 568,
#       "end_char": 572,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 138,
#       "text": "لم",
#       "start_char": 573,
#       "end_char": 575,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 139,
#       "text": "أكن",
#       "start_char": 576,
#       "end_char": 579,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 140,
#       "text": "أخاف",
#       "start_char": 580,
#       "end_char": 584,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 141,
#       "text": "أبدا",
#       "start_char": 585,
#       "end_char": 589,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 142,
#       "text": "من",
#       "start_char": 590,
#       "end_char": 592,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 143,
#       "text": "تلك",
#       "start_char": 593,
#       "end_char": 596,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 144,
#       "text": "المواجهة",
#       "start_char": 597,
#       "end_char": 605,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         145,
#         146
#       ],
#       "text": "لأنني",
#       "start_char": 606,
#       "end_char": 611,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 145,
#       "text": "لأن"
#     },
#     {
#       "id": 146,
#       "text": "ني"
#     },
#     {
#       "id": 147,
#       "text": "واثق",
#       "start_char": 612,
#       "end_char": 616,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 148,
#       "text": "في",
#       "start_char": 617,
#       "end_char": 619,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 149,
#       "text": "متانة",
#       "start_char": 620,
#       "end_char": 625,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 150,
#       "text": "وقوة",
#       "start_char": 626,
#       "end_char": 630,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         151,
#         152
#       ],
#       "text": "مسبحتنا",
#       "start_char": 631,
#       "end_char": 638,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 151,
#       "text": "مسبحة"
#     },
#     {
#       "id": 152,
#       "text": "نا"
#     },
#     {
#       "id": 153,
#       "text": "الوطنية",
#       "start_char": 639,
#       "end_char": 646,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ],
#       "misc": "SpacesAfter=\\u00A0\\s\\u00A0\\s"
#     },
#     {
#       "id": [
#         154,
#         155
#       ],
#       "text": "لدي",
#       "start_char": 650,
#       "end_char": 653,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 154,
#       "text": "لدي"
#     },
#     {
#       "id": 155,
#       "text": "ي"
#     },
#     {
#       "id": 156,
#       "text": "مسبحة",
#       "start_char": 654,
#       "end_char": 659,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 157,
#       "text": "مطعمة",
#       "start_char": 660,
#       "end_char": 665,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         158,
#         159
#       ],
#       "text": "بالفضة",
#       "start_char": 666,
#       "end_char": 672,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 158,
#       "text": "ب"
#     },
#     {
#       "id": 159,
#       "text": "الفضة"
#     },
#     {
#       "id": [
#         160,
#         161
#       ],
#       "text": "عمرها",
#       "start_char": 673,
#       "end_char": 678,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 160,
#       "text": "عمر"
#     },
#     {
#       "id": 161,
#       "text": "ها"
#     },
#     {
#       "id": 162,
#       "text": "ثلاثون",
#       "start_char": 679,
#       "end_char": 685,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 163,
#       "text": "عاما",
#       "start_char": 686,
#       "end_char": 690,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         164,
#         165
#       ],
#       "text": "لها",
#       "start_char": 691,
#       "end_char": 694,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 164,
#       "text": "ل"
#     },
#     {
#       "id": 165,
#       "text": "ها"
#     },
#     {
#       "id": 166,
#       "text": "ذكريات",
#       "start_char": 695,
#       "end_char": 701,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 167,
#       "text": "طيبة",
#       "start_char": 702,
#       "end_char": 706,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 168,
#       "text": "في",
#       "start_char": 707,
#       "end_char": 709,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 169,
#       "text": "نفسي",
#       "start_char": 710,
#       "end_char": 714,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 170,
#       "text": "لكني",
#       "start_char": 715,
#       "end_char": 719,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 171,
#       "text": "لا",
#       "start_char": 720,
#       "end_char": 722,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 172,
#       "text": "أحبذ",
#       "start_char": 723,
#       "end_char": 727,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 173,
#       "text": "أن",
#       "start_char": 728,
#       "end_char": 730,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         174,
#         175
#       ],
#       "text": "أظهرها",
#       "start_char": 731,
#       "end_char": 737,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 174,
#       "text": "أظهر"
#     },
#     {
#       "id": 175,
#       "text": "ها"
#     },
#     {
#       "id": 176,
#       "text": "ليس",
#       "start_char": 738,
#       "end_char": 741,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         177,
#         178
#       ],
#       "text": "لأني",
#       "start_char": 742,
#       "end_char": 746,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 177,
#       "text": "لأن"
#     },
#     {
#       "id": 178,
#       "text": "ي"
#     },
#     {
#       "id": 179,
#       "text": "أخشى",
#       "start_char": 747,
#       "end_char": 751,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         180,
#         181
#       ],
#       "text": "عليها",
#       "start_char": 752,
#       "end_char": 757,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 180,
#       "text": "علي"
#     },
#     {
#       "id": 181,
#       "text": "ها"
#     },
#     {
#       "id": 182,
#       "text": "الانفراط",
#       "start_char": 758,
#       "end_char": 766,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 183,
#       "text": "حتى",
#       "start_char": 767,
#       "end_char": 770,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 184,
#       "text": "حين",
#       "start_char": 771,
#       "end_char": 774,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 185,
#       "text": "أدبك",
#       "start_char": 775,
#       "end_char": 779,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         186,
#         187
#       ],
#       "text": "بها",
#       "start_char": 780,
#       "end_char": 783,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 186,
#       "text": "ب"
#     },
#     {
#       "id": 187,
#       "text": "ها"
#     },
#     {
#       "id": 188,
#       "text": "لا",
#       "start_char": 784,
#       "end_char": 786,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 189,
#       "text": "سمح",
#       "start_char": 787,
#       "end_char": 790,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 190,
#       "text": "الله",
#       "start_char": 791,
#       "end_char": 795,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 191,
#       "text": "بل",
#       "start_char": 796,
#       "end_char": 798,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         192,
#         194
#       ],
#       "text": "لأنك",
#       "start_char": 799,
#       "end_char": 803,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 192,
#       "text": "ل"
#     },
#     {
#       "id": 193,
#       "text": "أن"
#     },
#     {
#       "id": 194,
#       "text": "ك"
#     },
#     {
#       "id": 195,
#       "text": "قد",
#       "start_char": 804,
#       "end_char": 806,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 196,
#       "text": "تقف",
#       "start_char": 807,
#       "end_char": 810,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 197,
#       "text": "مع",
#       "start_char": 811,
#       "end_char": 813,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         198,
#         199
#       ],
#       "text": "أحدهم",
#       "start_char": 814,
#       "end_char": 819,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 198,
#       "text": "أحد"
#     },
#     {
#       "id": 199,
#       "text": "هم"
#     },
#     {
#       "id": 200,
#       "text": "فيمد",
#       "start_char": 820,
#       "end_char": 824,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 201,
#       "text": "يده",
#       "start_char": 825,
#       "end_char": 828,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 202,
#       "text": "لا",
#       "start_char": 829,
#       "end_char": 831,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 203,
#       "text": "شعوريا",
#       "start_char": 832,
#       "end_char": 838,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         204,
#         206
#       ],
#       "text": "ويأخذها",
#       "start_char": 839,
#       "end_char": 846,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 204,
#       "text": "و"
#     },
#     {
#       "id": 205,
#       "text": "يأخذ"
#     },
#     {
#       "id": 206,
#       "text": "ها"
#     },
#     {
#       "id": [
#         207,
#         208
#       ],
#       "text": "يتأملها",
#       "start_char": 847,
#       "end_char": 854,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 207,
#       "text": "يتأمل"
#     },
#     {
#       "id": 208,
#       "text": "ها"
#     },
#     {
#       "id": [
#         209,
#         210
#       ],
#       "text": "ويداعب",
#       "start_char": 855,
#       "end_char": 861,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 209,
#       "text": "و"
#     },
#     {
#       "id": 210,
#       "text": "يداعب"
#     },
#     {
#       "id": [
#         211,
#         212
#       ],
#       "text": "شراشيبها",
#       "start_char": 862,
#       "end_char": 870,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 211,
#       "text": "شراشيب"
#     },
#     {
#       "id": 212,
#       "text": "ها"
#     },
#     {
#       "id": [
#         213,
#         214
#       ],
#       "text": "ويتفحص",
#       "start_char": 871,
#       "end_char": 877,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 213,
#       "text": "و"
#     },
#     {
#       "id": 214,
#       "text": "يتفحص"
#     },
#     {
#       "id": [
#         215,
#         216
#       ],
#       "text": "حجارتها",
#       "start_char": 878,
#       "end_char": 885,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 215,
#       "text": "حجارة"
#     },
#     {
#       "id": 216,
#       "text": "ها"
#     },
#     {
#       "id": [
#         217,
#         218
#       ],
#       "text": "ويسألك",
#       "start_char": 886,
#       "end_char": 892,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 217,
#       "text": "و"
#     },
#     {
#       "id": 218,
#       "text": "يسألك"
#     },
#     {
#       "id": 219,
#       "text": "إن",
#       "start_char": 893,
#       "end_char": 895,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 220,
#       "text": "كانت",
#       "start_char": 896,
#       "end_char": 900,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 221,
#       "text": "حقا",
#       "start_char": 901,
#       "end_char": 904,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 222,
#       "text": "فيروزا",
#       "start_char": 905,
#       "end_char": 911,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         223,
#         224
#       ],
#       "text": "فتهز",
#       "start_char": 912,
#       "end_char": 916,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 223,
#       "text": "ف"
#     },
#     {
#       "id": 224,
#       "text": "تهز"
#     },
#     {
#       "id": 225,
#       "text": "رأسك",
#       "start_char": 917,
#       "end_char": 921,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 226,
#       "text": "مؤكدا",
#       "start_char": 922,
#       "end_char": 927,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 227,
#       "text": "ثم",
#       "start_char": 928,
#       "end_char": 930,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 228,
#       "text": "يكر",
#       "start_char": 931,
#       "end_char": 934,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         229,
#         230
#       ],
#       "text": "عليها",
#       "start_char": 935,
#       "end_char": 940,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 229,
#       "text": "علي"
#     },
#     {
#       "id": 230,
#       "text": "ها"
#     },
#     {
#       "id": 231,
#       "text": "مرتين",
#       "start_char": 941,
#       "end_char": 946,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         232,
#         233
#       ],
#       "text": "ويغافلك",
#       "start_char": 947,
#       "end_char": 954,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 232,
#       "text": "و"
#     },
#     {
#       "id": 233,
#       "text": "يغافلك"
#     },
#     {
#       "id": [
#         234,
#         236
#       ],
#       "text": "ويدسها",
#       "start_char": 955,
#       "end_char": 961,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 234,
#       "text": "و"
#     },
#     {
#       "id": 235,
#       "text": "يدس"
#     },
#     {
#       "id": 236,
#       "text": "ها"
#     },
#     {
#       "id": 237,
#       "text": "في",
#       "start_char": 962,
#       "end_char": 964,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         238,
#         239
#       ],
#       "text": "جيبه",
#       "start_char": 965,
#       "end_char": 969,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 238,
#       "text": "جيب"
#     },
#     {
#       "id": 239,
#       "text": "ه"
#     },
#     {
#       "id": [
#         240,
#         241
#       ],
#       "text": "ويمضي",
#       "start_char": 970,
#       "end_char": 975,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 240,
#       "text": "و"
#     },
#     {
#       "id": 241,
#       "text": "يمضي"
#     },
#     {
#       "id": 242,
#       "text": "في",
#       "start_char": 976,
#       "end_char": 978,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 243,
#       "text": "سوق",
#       "start_char": 979,
#       "end_char": 982,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 244,
#       "text": "شعبية",
#       "start_char": 983,
#       "end_char": 988,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 245,
#       "text": "كنت",
#       "start_char": 989,
#       "end_char": 992,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 246,
#       "text": "أتردد",
#       "start_char": 993,
#       "end_char": 998,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         247,
#         248
#       ],
#       "text": "فيه",
#       "start_char": 999,
#       "end_char": 1002,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 247,
#       "text": "في"
#     },
#     {
#       "id": 248,
#       "text": "ه"
#     },
#     {
#       "id": 249,
#       "text": "على",
#       "start_char": 1003,
#       "end_char": 1006,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 250,
#       "text": "باعة",
#       "start_char": 1007,
#       "end_char": 1011,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 251,
#       "text": "المسابح",
#       "start_char": 1012,
#       "end_char": 1019,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 252,
#       "text": "في",
#       "start_char": 1020,
#       "end_char": 1022,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 253,
#       "text": "بغداد",
#       "start_char": 1023,
#       "end_char": 1028,
#       "ner": "S-LOC",
#       "multi_ner": [
#         "S-LOC"
#       ]
#     },
#     {
#       "id": 254,
#       "text": "أسأل",
#       "start_char": 1029,
#       "end_char": 1033,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         255,
#         256
#       ],
#       "text": "وأستفسر",
#       "start_char": 1034,
#       "end_char": 1041,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 255,
#       "text": "و"
#     },
#     {
#       "id": 256,
#       "text": "أستفسر"
#     },
#     {
#       "id": 257,
#       "text": "عن",
#       "start_char": 1042,
#       "end_char": 1044,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 258,
#       "text": "كل",
#       "start_char": 1045,
#       "end_char": 1047,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 259,
#       "text": "شاردة",
#       "start_char": 1048,
#       "end_char": 1053,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 260,
#       "text": "حتى",
#       "start_char": 1054,
#       "end_char": 1057,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 261,
#       "text": "كدت",
#       "start_char": 1058,
#       "end_char": 1061,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 262,
#       "text": "أصير",
#       "start_char": 1062,
#       "end_char": 1066,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 263,
#       "text": "خبيرا",
#       "start_char": 1067,
#       "end_char": 1072,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         264,
#         266
#       ],
#       "text": "بأنواعها",
#       "start_char": 1073,
#       "end_char": 1081,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 264,
#       "text": "ب"
#     },
#     {
#       "id": 265,
#       "text": "أنواع"
#     },
#     {
#       "id": 266,
#       "text": "ها"
#     },
#     {
#       "id": 267,
#       "text": "قادرا",
#       "start_char": 1082,
#       "end_char": 1087,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 268,
#       "text": "على",
#       "start_char": 1088,
#       "end_char": 1091,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 269,
#       "text": "أن",
#       "start_char": 1092,
#       "end_char": 1094,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 270,
#       "text": "أعرف",
#       "start_char": 1095,
#       "end_char": 1099,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 271,
#       "text": "الياقوت",
#       "start_char": 1100,
#       "end_char": 1107,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 272,
#       "text": "من",
#       "start_char": 1108,
#       "end_char": 1110,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 273,
#       "text": "السندلس",
#       "start_char": 1111,
#       "end_char": 1118,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 274,
#       "text": "من",
#       "start_char": 1119,
#       "end_char": 1121,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 275,
#       "text": "الفيروز",
#       "start_char": 1122,
#       "end_char": 1129,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         276,
#         277
#       ],
#       "text": "والزبرجد",
#       "start_char": 1130,
#       "end_char": 1138,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 276,
#       "text": "و"
#     },
#     {
#       "id": 277,
#       "text": "الزبرجد"
#     },
#     {
#       "id": [
#         278,
#         279
#       ],
#       "text": "وكل",
#       "start_char": 1139,
#       "end_char": 1142,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 278,
#       "text": "و"
#     },
#     {
#       "id": 279,
#       "text": "كل"
#     },
#     {
#       "id": 280,
#       "text": "الأحجار",
#       "start_char": 1143,
#       "end_char": 1150,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 281,
#       "text": "الكريمة",
#       "start_char": 1151,
#       "end_char": 1158,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 282,
#       "text": "بل",
#       "start_char": 1159,
#       "end_char": 1161,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         283,
#         284
#       ],
#       "text": "وأن",
#       "start_char": 1162,
#       "end_char": 1165,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 283,
#       "text": "و"
#     },
#     {
#       "id": 284,
#       "text": "أن"
#     },
#     {
#       "id": 285,
#       "text": "أفصل",
#       "start_char": 1166,
#       "end_char": 1170,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 286,
#       "text": "الألون",
#       "start_char": 1171,
#       "end_char": 1177,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 287,
#       "text": "الطبيعية",
#       "start_char": 1178,
#       "end_char": 1186,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 288,
#       "text": "عن",
#       "start_char": 1187,
#       "end_char": 1189,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 289,
#       "text": "الصناعية",
#       "start_char": 1190,
#       "end_char": 1198,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 290,
#       "text": "مهما",
#       "start_char": 1199,
#       "end_char": 1203,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 291,
#       "text": "كانت",
#       "start_char": 1204,
#       "end_char": 1208,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 292,
#       "text": "دقة",
#       "start_char": 1209,
#       "end_char": 1212,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         293,
#         294
#       ],
#       "text": "صنعها",
#       "start_char": 1213,
#       "end_char": 1218,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 293,
#       "text": "صنع"
#     },
#     {
#       "id": 294,
#       "text": "ها"
#     },
#     {
#       "id": [
#         295,
#         296
#       ],
#       "text": "وأميز",
#       "start_char": 1219,
#       "end_char": 1224,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 295,
#       "text": "و"
#     },
#     {
#       "id": 296,
#       "text": "أميز"
#     },
#     {
#       "id": 297,
#       "text": "المسابح",
#       "start_char": 1225,
#       "end_char": 1232,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 298,
#       "text": "التي",
#       "start_char": 1233,
#       "end_char": 1237,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 299,
#       "text": "تفوح",
#       "start_char": 1238,
#       "end_char": 1242,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 300,
#       "text": "عطرا",
#       "start_char": 1243,
#       "end_char": 1247,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 301,
#       "text": "كلما",
#       "start_char": 1248,
#       "end_char": 1252,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 302,
#       "text": "فركت",
#       "start_char": 1253,
#       "end_char": 1257,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         303,
#         304
#       ],
#       "text": "حجارتها",
#       "start_char": 1258,
#       "end_char": 1265,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 303,
#       "text": "حجارة"
#     },
#     {
#       "id": 304,
#       "text": "ها"
#     },
#     {
#       "id": 305,
#       "text": "في",
#       "start_char": 1266,
#       "end_char": 1268,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 306,
#       "text": "راحتيك",
#       "start_char": 1269,
#       "end_char": 1275,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         307,
#         308
#       ],
#       "text": "وأقدر",
#       "start_char": 1276,
#       "end_char": 1281,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 307,
#       "text": "و"
#     },
#     {
#       "id": 308,
#       "text": "أقدر"
#     },
#     {
#       "id": [
#         309,
#         310
#       ],
#       "text": "قيمتها",
#       "start_char": 1282,
#       "end_char": 1288,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 309,
#       "text": "قيمة"
#     },
#     {
#       "id": 310,
#       "text": "ها"
#     },
#     {
#       "id": [
#         311,
#         313
#       ],
#       "text": "وثمنها",
#       "start_char": 1289,
#       "end_char": 1295,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ],
#       "misc": "SpacesAfter=\\s\\u00A0\\s"
#     },
#     {
#       "id": 311,
#       "text": "و"
#     },
#     {
#       "id": 312,
#       "text": "ثمن"
#     },
#     {
#       "id": 313,
#       "text": "ها"
#     },
#     {
#       "id": 314,
#       "text": "في",
#       "start_char": 1298,
#       "end_char": 1300,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 315,
#       "text": "ذات",
#       "start_char": 1301,
#       "end_char": 1304,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 316,
#       "text": "السوق",
#       "start_char": 1305,
#       "end_char": 1310,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 317,
#       "text": "قال",
#       "start_char": 1311,
#       "end_char": 1314,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 318,
#       "text": "لي",
#       "start_char": 1315,
#       "end_char": 1317,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 319,
#       "text": "بائع",
#       "start_char": 1318,
#       "end_char": 1322,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 320,
#       "text": "مسن",
#       "start_char": 1323,
#       "end_char": 1326,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 321,
# ...
#       "text": "فقط",
#       "start_char": 1530,
#       "end_char": 1533,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         372,
#         373
#       ],
#       "text": "ولا",
#       "start_char": 1534,
#       "end_char": 1537,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 372,
#       "text": "و"
#     },
#     {
#       "id": 373,
#       "text": "لا"
#     },
#     {
#       "id": 374,
#       "text": "نلتفت",
#       "start_char": 1538,
#       "end_char": 1543,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 375,
#       "text": "إلى",
#       "start_char": 1544,
#       "end_char": 1547,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 376,
#       "text": "الخيط",
#       "start_char": 1548,
#       "end_char": 1553,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 377,
#       "text": "الذي",
#       "start_char": 1554,
#       "end_char": 1558,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 378,
#       "text": "ينظم",
#       "start_char": 1559,
#       "end_char": 1563,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 379,
#       "text": "هذه",
#       "start_char": 1564,
#       "end_char": 1567,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 380,
#       "text": "الحبات",
#       "start_char": 1568,
#       "end_char": 1574,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         381,
#         382
#       ],
#       "text": "فهو",
#       "start_char": 1575,
#       "end_char": 1578,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 381,
#       "text": "ف"
#     },
#     {
#       "id": 382,
#       "text": "هو"
#     },
#     {
#       "id": 383,
#       "text": "متوار",
#       "start_char": 1579,
#       "end_char": 1584,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 384,
#       "text": "مخفي",
#       "start_char": 1585,
#       "end_char": 1589,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 385,
#       "text": "عن",
#       "start_char": 1590,
#       "end_char": 1592,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 386,
#       "text": "الأنظار",
#       "start_char": 1593,
#       "end_char": 1600,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         387,
#         388
#       ],
#       "text": "لكنه",
#       "start_char": 1601,
#       "end_char": 1605,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 387,
#       "text": "لٰكن"
#     },
#     {
#       "id": 388,
#       "text": "ه"
#     },
#     {
#       "id": 389,
#       "text": "موجود",
#       "start_char": 1606,
#       "end_char": 1611,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 390,
#       "text": "لا",
#       "start_char": 1612,
#       "end_char": 1614,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 391,
#       "text": "نحس",
#       "start_char": 1615,
#       "end_char": 1618,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         392,
#         393
#       ],
#       "text": "به",
#       "start_char": 1619,
#       "end_char": 1621,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 392,
#       "text": "ب"
#     },
#     {
#       "id": 393,
#       "text": "ه"
#     },
#     {
#       "id": 394,
#       "text": "إلا",
#       "start_char": 1622,
#       "end_char": 1625,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 395,
#       "text": "حين",
#       "start_char": 1626,
#       "end_char": 1629,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 396,
#       "text": "ينقطع",
#       "start_char": 1630,
#       "end_char": 1635,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         397,
#         399
#       ],
#       "text": "وعندها",
#       "start_char": 1636,
#       "end_char": 1642,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 397,
#       "text": "و"
#     },
#     {
#       "id": 398,
#       "text": "عند"
#     },
#     {
#       "id": 399,
#       "text": "ها"
#     },
#     {
#       "id": [
#         400,
#         401
#       ],
#       "text": "فإن",
#       "start_char": 1643,
#       "end_char": 1646,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 400,
#       "text": "ف"
#     },
#     {
#       "id": 401,
#       "text": "إن"
#     },
#     {
#       "id": 402,
#       "text": "المسبحة",
#       "start_char": 1647,
#       "end_char": 1654,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 403,
#       "text": "لن",
#       "start_char": 1655,
#       "end_char": 1657,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 404,
#       "text": "تعود",
#       "start_char": 1658,
#       "end_char": 1662,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 405,
#       "text": "مسبحة",
#       "start_char": 1663,
#       "end_char": 1668,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         406,
#         407
#       ],
#       "text": "والعقد",
#       "start_char": 1669,
#       "end_char": 1675,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 406,
#       "text": "و"
#     },
#     {
#       "id": 407,
#       "text": "العقد"
#     },
#     {
#       "id": 408,
#       "text": "لن",
#       "start_char": 1676,
#       "end_char": 1678,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 409,
#       "text": "يعود",
#       "start_char": 1679,
#       "end_char": 1683,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 410,
#       "text": "عقدا",
#       "start_char": 1684,
#       "end_char": 1688,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 411,
#       "text": "بل",
#       "start_char": 1689,
#       "end_char": 1691,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 412,
#       "text": "مجرد",
#       "start_char": 1692,
#       "end_char": 1696,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 413,
#       "text": "حبات",
#       "start_char": 1697,
#       "end_char": 1701,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 414,
#       "text": "متناثرة",
#       "start_char": 1702,
#       "end_char": 1709,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         415,
#         416
#       ],
#       "text": "تطؤها",
#       "start_char": 1710,
#       "end_char": 1715,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 415,
#       "text": "تطؤ"
#     },
#     {
#       "id": 416,
#       "text": "ها"
#     },
#     {
#       "id": 417,
#       "text": "الأقدام",
#       "start_char": 1716,
#       "end_char": 1723,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         418,
#         420
#       ],
#       "text": "ويعفرها",
#       "start_char": 1724,
#       "end_char": 1731,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 418,
#       "text": "و"
#     },
#     {
#       "id": 419,
#       "text": "يعفر"
#     },
#     {
#       "id": 420,
#       "text": "ها"
#     },
#     {
#       "id": 421,
#       "text": "التراب",
#       "start_char": 1732,
#       "end_char": 1738,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 422,
#       "text": "حين",
#       "start_char": 1739,
#       "end_char": 1742,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 423,
#       "text": "يكون",
#       "start_char": 1743,
#       "end_char": 1747,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 424,
#       "text": "خيط",
#       "start_char": 1748,
#       "end_char": 1751,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         425,
#         426
#       ],
#       "text": "مسبحتك",
#       "start_char": 1752,
#       "end_char": 1758,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 425,
#       "text": "مسبحة"
#     },
#     {
#       "id": 426,
#       "text": "ك"
#     },
#     {
#       "id": 427,
#       "text": "ضعيفا",
#       "start_char": 1759,
#       "end_char": 1764,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 428,
#       "text": "يحق",
#       "start_char": 1765,
#       "end_char": 1768,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         429,
#         430
#       ],
#       "text": "لك",
#       "start_char": 1769,
#       "end_char": 1771,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 429,
#       "text": "ل"
#     },
#     {
#       "id": 430,
#       "text": "ك"
#     },
#     {
#       "id": 431,
#       "text": "أن",
#       "start_char": 1772,
#       "end_char": 1774,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 432,
#       "text": "تخاف",
#       "start_char": 1775,
#       "end_char": 1779,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         433,
#         434
#       ],
#       "text": "عليها",
#       "start_char": 1780,
#       "end_char": 1785,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 433,
#       "text": "علي"
#     },
#     {
#       "id": 434,
#       "text": "ها"
#     },
#     {
#       "id": [
#         435,
#         436
#       ],
#       "text": "لكن",
#       "start_char": 1786,
#       "end_char": 1789,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 435,
#       "text": "ل"
#     },
#     {
#       "id": 436,
#       "text": "كن"
#     },
#     {
#       "id": 437,
#       "text": "حين",
#       "start_char": 1790,
#       "end_char": 1793,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 438,
#       "text": "تكون",
#       "start_char": 1794,
#       "end_char": 1798,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 439,
#       "text": "واثقا",
#       "start_char": 1799,
#       "end_char": 1804,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 440,
#       "text": "من",
#       "start_char": 1805,
#       "end_char": 1807,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 441,
#       "text": "قوة",
#       "start_char": 1808,
#       "end_char": 1811,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 442,
#       "text": "ذلك",
#       "start_char": 1812,
#       "end_char": 1815,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 443,
#       "text": "الخيط",
#       "start_char": 1816,
#       "end_char": 1821,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         444,
#         446
#       ],
#       "text": "ومتانته",
#       "start_char": 1822,
#       "end_char": 1829,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 444,
#       "text": "و"
#     },
#     {
#       "id": 445,
#       "text": "متانة"
#     },
#     {
#       "id": 446,
#       "text": "ه"
#     },
#     {
#       "id": [
#         447,
#         449
#       ],
#       "text": "وأصالته",
#       "start_char": 1830,
#       "end_char": 1837,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 447,
#       "text": "و"
#     },
#     {
#       "id": 448,
#       "text": "أصالت"
#     },
#     {
#       "id": 449,
#       "text": "ه"
#     },
#     {
#       "id": [
#         450,
#         451
#       ],
#       "text": "لأنه",
#       "start_char": 1838,
#       "end_char": 1842,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 450,
#       "text": "لأن"
#     },
#     {
#       "id": 451,
#       "text": "ه"
#     },
#     {
#       "id": 452,
#       "text": "الجوهر",
#       "start_char": 1843,
#       "end_char": 1849,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 453,
#       "text": "لا",
#       "start_char": 1850,
#       "end_char": 1852,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 454,
#       "text": "يبقى",
#       "start_char": 1853,
#       "end_char": 1857,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         455,
#         456
#       ],
#       "text": "عليك",
#       "start_char": 1858,
#       "end_char": 1862,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 455,
#       "text": "علي"
#     },
#     {
#       "id": 456,
#       "text": "ك"
#     },
#     {
#       "id": 457,
#       "text": "إلا",
#       "start_char": 1863,
#       "end_char": 1866,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 458,
#       "text": "أن",
#       "start_char": 1867,
#       "end_char": 1869,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         459,
#         460
#       ],
#       "text": "تنتبه",
#       "start_char": 1870,
#       "end_char": 1875,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 459,
#       "text": "تنتب"
#     },
#     {
#       "id": 460,
#       "text": "ه"
#     },
#     {
#       "id": 461,
#       "text": "من",
#       "start_char": 1876,
#       "end_char": 1878,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 462,
#       "text": "يد",
#       "start_char": 1879,
#       "end_char": 1881,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 463,
#       "text": "الغرباء",
#       "start_char": 1882,
#       "end_char": 1889,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 464,
#       "text": "أن",
#       "start_char": 1890,
#       "end_char": 1892,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         465,
#         466
#       ],
#       "text": "تخطفها",
#       "start_char": 1893,
#       "end_char": 1899,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 465,
#       "text": "تخطف"
#     },
#     {
#       "id": 466,
#       "text": "ها"
#     },
#     {
#       "id": [
#         467,
#         468
#       ],
#       "text": "منك",
#       "start_char": 1900,
#       "end_char": 1903,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 467,
#       "text": "من"
#     },
#     {
#       "id": 468,
#       "text": "ك"
#     },
#     {
#       "id": [
#         469,
#         470
#       ],
#       "text": "وتغافلك",
#       "start_char": 1904,
#       "end_char": 1911,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 469,
#       "text": "و"
#     },
#     {
#       "id": 470,
#       "text": "تغافلك"
#     },
#     {
#       "id": [
#         471,
#         472
#       ],
#       "text": "وتدسها",
#       "start_char": 1912,
#       "end_char": 1918,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 471,
#       "text": "و"
#     },
#     {
#       "id": 472,
#       "text": "تدسها"
#     },
#     {
#       "id": 473,
#       "text": "في",
#       "start_char": 1919,
#       "end_char": 1921,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": [
#         474,
#         475
#       ],
#       "text": "جيبها",
#       "start_char": 1922,
#       "end_char": 1927,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ],
#       "misc": "SpaceAfter=No"
#     },
#     {
#       "id": 474,
#       "text": "جيب"
#     },
#     {
#       "id": 475,
#       "text": "ها"
#     }
#   ]
# ]
# [{
#   "text": "غزة",
#   "type": "LOC",
#   "start_char": 315,
#   "end_char": 318
# }, {
#   "text": "وفلسطين",
#   "type": "LOC",
#   "start_char": 319,
#   "end_char": 326
# }, {
#   "text": "بغداد",
#   "type": "LOC",
#   "start_char": 1023,
#   "end_char": 1028
# }]
